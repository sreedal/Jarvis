# %% [markdown]
# **Commands to start Development Environment**
# 1. Install Docker-Desktop, Login
# 2. docker run (Jupyter notebook - should update command once loggeing out)
#     1. docker run --name devenv -it --entrypoint=/bin/bash -p 8880:8888 -v C:\users\srmenon\Documents:/notebooks jupyter/tensorflow-notebook
#
# 3. cd /notebooks/
# 4. nohup jupyter notebook --port 8880 --allow-root &
# 5. jupyter notebook list

# %%
# Schedule a job to run every hour
import schedule, time, datetime
def test():
    print("Test")

schedule.clear()
schedule.every(10).seconds.do(test)

while datetime.datetime.now()<datetime.datetime(2019,11,21,10,11,0,0):
    schedule.run_pending()
    print(datetime.datetime.now())
    time.sleep(5)
    
schedule.clear()

# %%
# !pip install twitter
# !pip install feedparser
# !pip install schedule
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 892kB/s eta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
#      |████████████████████████████████| 194kB 944kB/s eta 0:00:01
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp37-none-any.whl size=44940 sha256=e21bb44204e675193a5c1aa5346256c9355cd6913479716eb0905dd2e6555d83
#   Stored in directory: /home/jovyan/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# Installing collected packages: feedparser
# Successfully installed feedparser-5.2.1
# Collecting schedule
#   Downloading https://files.pythonhosted.org/packages/57/22/3a709462eb02412bd1145f6e53604f36bba191e3e4e397bea4a718fec38c/schedule-0.6.0-py2.py3-none-any.whl
# Installing collected packages: schedule
# Successfully installed schedule-0.6.0

# %%
# Authenticate with Twitter & search
# https://pypi.org/project/twitter/
# https://developer.twitter.com/en/apps/17019807
from twitter import *
t = Twitter(auth=OAuth(consumer_key="nDwKHutvaskyGecZkCS1SiYY8", consumer_secret="zlQdJIuFUGGglbMO2kYMk6oNLFztzipxhRANNz5q5gqfn1tGb1", token="73568030-GqfoqkfWRhqhARS9uzz51vg1UGSV7AGRaOxDkAurZ", token_secret="1kiHGfyDfO7gcaJbGFnr3lnLA3vXc8ti9hJhj1lnTTvEm"))
t.search.tweets(q="$MSFT")
# Out:
# {'statuses': [{'created_at': 'Sat Dec 07 19:12:08 +0000 2019',
#    'id': 1203391759503560713,
#    'id_str': '1203391759503560713',
#    'text': '$MSFT $WMT $AMZN:\n\nHow the 1% donate to charities differently to everyone else:\n\nhttps://t.co/aZrhHNbbRs',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'MSFT', 'indices': [0, 5]},
#      {'text': 'WMT', 'indices': [6, 10]},
#      {'text': 'AMZN', 'indices': [11, 16]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/aZrhHNbbRs',
#       'expanded_url': 'https://www.StockNewsWires.com/msft-wmt-amzn-how-the-1-donate-to-charities-differently-to-everyone-else/',
#       'display_url': 'StockNewsWires.com/msft-wmt-amzn-…',
#       'indices': [81, 104]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.newsflowing.com" rel="nofollow">NFIG</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2342215530,
#     'id_str': '2342215530',
#     'name': 'Breaking News Now',
#     'screen_name': 'newswithvalue',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1022,
#     'friends_count': 0,
#     'listed_count': 157,
#     'created_at': 'Thu Feb 13 16:14:12 +0000 2014',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 435946,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/544036492876591104/7QJIB-XK_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/544036492876591104/7QJIB-XK_normal.jpeg',
#     'profile_link_color': 'CC3366',
#     'profile_sidebar_border_color': 'DBE9ED',
#     'profile_sidebar_fill_color': 'E6F6F9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 19:06:56 +0000 2019',
#    'id': 1203390451862167553,
#    'id_str': '1203390451862167553',
#    'text': "You're gonna sell yourself $TWTR.... who's buying?.... Facebook $FB, Amazon $AMZN, Microsoft  $MSFT or Alphabet… https://t.co/WnZwAL8v4n",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'TWTR', 'indices': [27, 32]},
#      {'text': 'FB', 'indices': [64, 67]},
#      {'text': 'AMZN', 'indices': [76, 81]},
#      {'text': 'MSFT', 'indices': [94, 99]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WnZwAL8v4n',
#       'expanded_url': 'https://twitter.com/i/web/status/1203390451862167553',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18633659,
#     'id_str': '18633659',
#     'name': 'JuanMa!',
#     'screen_name': 'Dj_Zerok',
#     'location': 'Panamá - Bogotá',
#     'description': 'Economista colombiano navegando en el Marketing, Big Data y ETFs. \nExpat en Panamá.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 904,
#     'friends_count': 775,
#     'listed_count': 86,
#     'created_at': 'Mon Jan 05 15:05:00 +0000 2009',
#     'favourites_count': 13985,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 34639,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/903394374406557700/ILfY3FfI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/903394374406557700/ILfY3FfI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18633659/1467835739',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '0D0D0F',
#     'profile_text_color': 'FFFFFF',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '00b9b6e734ad1849',
#     'url': 'https://api.twitter.com/1.1/geo/id/00b9b6e734ad1849.json',
#     'place_type': 'city',
#     'name': 'Chorrillos',
#     'full_name': 'Chorrillos, Peru',
#     'country_code': 'PE',
#     'country': 'Peru',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-77.0400619178694, -12.232257030261],
#        [-76.9698889232541, -12.232257030261],
#        [-76.9698889232541, -12.1566819563191],
#        [-77.0400619178694, -12.1566819563191]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1203075203020021761,
#    'quoted_status_id_str': '1203075203020021761',
#    'quoted_status': {'created_at': 'Fri Dec 06 22:14:15 +0000 2019',
#     'id': 1203075203020021761,
#     'id_str': '1203075203020021761',
#     'text': 'We need to talk',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 783214,
#      'id_str': '783214',
#      'name': 'Twitter',
#      'screen_name': 'Twitter',
#      'location': 'Everywhere',
#      'description': 'What’s happening?!',
#      'url': 'https://t.co/TAXQpsHa5X',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/TAXQpsHa5X',
#          'expanded_url': 'https://about.twitter.com/',
#          'display_url': 'about.twitter.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 56784426,
#      'friends_count': 1,
#      'listed_count': 90431,
#      'created_at': 'Tue Feb 20 14:35:54 +0000 2007',
#      'favourites_count': 6352,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 12457,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'ACDED6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1111729635610382336/_65QFl7B_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1111729635610382336/_65QFl7B_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/783214/1556918042',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 41014,
#     'favorite_count': 206602,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 19:02:10 +0000 2019',
#    'id': 1203389252651892737,
#    'id_str': '1203389252651892737',
#    'text': 'RT @KirkSpano: Gold, Solar, "Smart Everything" &amp; Game Plan For 2020 #Crash2020  $GOLD $NEM $GDX $GDXJ $CDE $QQQ $GOOG $MSFT $AMZN $APPL $EN…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Crash2020', 'indices': [72, 82]}],
#     'symbols': [{'text': 'GOLD', 'indices': [84, 89]},
#      {'text': 'NEM', 'indices': [90, 94]},
#      {'text': 'GDX', 'indices': [95, 99]},
#      {'text': 'GDXJ', 'indices': [100, 105]},
#      {'text': 'CDE', 'indices': [106, 110]},
#      {'text': 'QQQ', 'indices': [111, 115]},
#      {'text': 'GOOG', 'indices': [116, 121]},
#      {'text': 'MSFT', 'indices': [122, 127]},
#      {'text': 'AMZN', 'indices': [128, 133]},
#      {'text': 'APPL', 'indices': [134, 139]}],
#     'user_mentions': [{'screen_name': 'KirkSpano',
#       'name': 'Kirk Spano',
#       'id': 407493118,
#       'id_str': '407493118',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 38650797,
#     'id_str': '38650797',
#     'name': 'Z',
#     'screen_name': 'IronFalcon77',
#     'location': "I'm with Elvis - everywhere",
#     'description': "Proficient in firearms, cooking and enjoy hiking and doing field research. All I can say is I've seen a lot of things most of you will never live to see.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 903,
#     'friends_count': 544,
#     'listed_count': 68,
#     'created_at': 'Fri May 08 11:49:38 +0000 2009',
#     'favourites_count': 7187,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 237682,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/203121555/me_close_up_normal.JPG',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/203121555/me_close_up_normal.JPG',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Dec 07 19:01:20 +0000 2019',
#     'id': 1203389042966114307,
#     'id_str': '1203389042966114307',
#     'text': 'Gold, Solar, "Smart Everything" &amp; Game Plan For 2020 #Crash2020  $GOLD $NEM $GDX $GDXJ $CDE $QQQ $GOOG $MSFT $AMZN… https://t.co/IU8iy33ZPF',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Crash2020', 'indices': [57, 67]}],
#      'symbols': [{'text': 'GOLD', 'indices': [69, 74]},
#       {'text': 'NEM', 'indices': [75, 79]},
#       {'text': 'GDX', 'indices': [80, 84]},
#       {'text': 'GDXJ', 'indices': [85, 90]},
#       {'text': 'CDE', 'indices': [91, 95]},
#       {'text': 'QQQ', 'indices': [96, 100]},
#       {'text': 'GOOG', 'indices': [101, 106]},
#       {'text': 'MSFT', 'indices': [107, 112]},
#       {'text': 'AMZN', 'indices': [113, 118]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/IU8iy33ZPF',
#        'expanded_url': 'https://twitter.com/i/web/status/1203389042966114307',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 407493118,
#      'id_str': '407493118',
#      'name': 'Kirk Spano',
#      'screen_name': 'KirkSpano',
#      'location': 'Wisconsin',
#      'description': '#Founder https://t.co/uvEzG0FD15 & https://t.co/14BPRrLKmN #investing #tech #crypto #solar #climatechange #sustainablity #ESG - #followme to avoid #Crash2020',
#      'url': 'https://t.co/VePS3b1mSC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/VePS3b1mSC',
#          'expanded_url': 'https://fundamentaltrends.com',
#          'display_url': 'fundamentaltrends.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/uvEzG0FD15',
#          'expanded_url': 'http://FundamentalTrends.com',
#          'display_url': 'FundamentalTrends.com',
#          'indices': [9, 32]},
#         {'url': 'https://t.co/14BPRrLKmN',
#          'expanded_url': 'http://BluemoundAM.com',
#          'display_url': 'BluemoundAM.com',
#          'indices': [35, 58]}]}},
#      'protected': False,
#      'followers_count': 2793,
#      'friends_count': 573,
#      'listed_count': 191,
#      'created_at': 'Tue Nov 08 04:36:08 +0000 2011',
#      'favourites_count': 7034,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 29220,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/465589642859790336/vJFPJHGh_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/465589642859790336/vJFPJHGh_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/407493118/1553285140',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 19:01:20 +0000 2019',
#    'id': 1203389042966114307,
#    'id_str': '1203389042966114307',
#    'text': 'Gold, Solar, "Smart Everything" &amp; Game Plan For 2020 #Crash2020  $GOLD $NEM $GDX $GDXJ $CDE $QQQ $GOOG $MSFT $AMZN… https://t.co/IU8iy33ZPF',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Crash2020', 'indices': [57, 67]}],
#     'symbols': [{'text': 'GOLD', 'indices': [69, 74]},
#      {'text': 'NEM', 'indices': [75, 79]},
#      {'text': 'GDX', 'indices': [80, 84]},
#      {'text': 'GDXJ', 'indices': [85, 90]},
#      {'text': 'CDE', 'indices': [91, 95]},
#      {'text': 'QQQ', 'indices': [96, 100]},
#      {'text': 'GOOG', 'indices': [101, 106]},
#      {'text': 'MSFT', 'indices': [107, 112]},
#      {'text': 'AMZN', 'indices': [113, 118]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/IU8iy33ZPF',
#       'expanded_url': 'https://twitter.com/i/web/status/1203389042966114307',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [120, 143]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 407493118,
#     'id_str': '407493118',
#     'name': 'Kirk Spano',
#     'screen_name': 'KirkSpano',
#     'location': 'Wisconsin',
#     'description': '#Founder https://t.co/uvEzG0FD15 & https://t.co/14BPRrLKmN #investing #tech #crypto #solar #climatechange #sustainablity #ESG - #followme to avoid #Crash2020',
#     'url': 'https://t.co/VePS3b1mSC',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VePS3b1mSC',
#         'expanded_url': 'https://fundamentaltrends.com',
#         'display_url': 'fundamentaltrends.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/uvEzG0FD15',
#         'expanded_url': 'http://FundamentalTrends.com',
#         'display_url': 'FundamentalTrends.com',
#         'indices': [9, 32]},
#        {'url': 'https://t.co/14BPRrLKmN',
#         'expanded_url': 'http://BluemoundAM.com',
#         'display_url': 'BluemoundAM.com',
#         'indices': [35, 58]}]}},
#     'protected': False,
#     'followers_count': 2793,
#     'friends_count': 573,
#     'listed_count': 191,
#     'created_at': 'Tue Nov 08 04:36:08 +0000 2011',
#     'favourites_count': 7034,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29220,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/465589642859790336/vJFPJHGh_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/465589642859790336/vJFPJHGh_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/407493118/1553285140',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:56:45 +0000 2019',
#    'id': 1203387888584540160,
#    'id_str': '1203387888584540160',
#    'text': '$aapl $amzn $agn $brk $bhc $abbv $msft $fb $crm $cmg $pfe $googl $wfc $jpm $bac $c $cs $ms $gs $ko $pep $ibm $iep… https://t.co/BzyTmZYXX6',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'aapl', 'indices': [0, 5]},
#      {'text': 'amzn', 'indices': [6, 11]},
#      {'text': 'agn', 'indices': [12, 16]},
#      {'text': 'brk', 'indices': [17, 21]},
#      {'text': 'bhc', 'indices': [22, 26]},
#      {'text': 'abbv', 'indices': [27, 32]},
#      {'text': 'msft', 'indices': [33, 38]},
#      {'text': 'fb', 'indices': [39, 42]},
#      {'text': 'crm', 'indices': [43, 47]},
#      {'text': 'cmg', 'indices': [48, 52]},
#      {'text': 'pfe', 'indices': [53, 57]},
#      {'text': 'googl', 'indices': [58, 64]},
#      {'text': 'wfc', 'indices': [65, 69]},
#      {'text': 'jpm', 'indices': [70, 74]},
#      {'text': 'bac', 'indices': [75, 79]},
#      {'text': 'c', 'indices': [80, 82]},
#      {'text': 'cs', 'indices': [83, 86]},
#      {'text': 'ms', 'indices': [87, 90]},
#      {'text': 'gs', 'indices': [91, 94]},
#      {'text': 'ko', 'indices': [95, 98]},
#      {'text': 'pep', 'indices': [99, 103]},
#      {'text': 'ibm', 'indices': [104, 108]},
#      {'text': 'iep', 'indices': [109, 113]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/BzyTmZYXX6',
#       'expanded_url': 'https://twitter.com/i/web/status/1203387888584540160',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 701988739803914242,
#     'id_str': '701988739803914242',
#     'name': 'Brian Firestone',
#     'screen_name': 'brianfires',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 849,
#     'friends_count': 222,
#     'listed_count': 21,
#     'created_at': 'Tue Feb 23 04:35:32 +0000 2016',
#     'favourites_count': 730,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 107,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/981145669992824832/I2PMDqwU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/981145669992824832/I2PMDqwU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/701988739803914242/1516438290',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:50:27 +0000 2019',
#    'id': 1203386305549176832,
#    'id_str': '1203386305549176832',
#    'text': 'why #Tradedeal &amp; #tariff rollback will help unitedstate firms in global sales as $ has peaked $EEM\n$IBM $SNPS $CDNS… https://t.co/YzONxBNVxW',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Tradedeal', 'indices': [4, 14]},
#      {'text': 'tariff', 'indices': [21, 28]}],
#     'symbols': [{'text': 'EEM', 'indices': [98, 102]},
#      {'text': 'IBM', 'indices': [103, 107]},
#      {'text': 'SNPS', 'indices': [108, 113]},
#      {'text': 'CDNS', 'indices': [114, 119]}],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/YzONxBNVxW',
#       'expanded_url': 'https://twitter.com/i/web/status/1203386305549176832',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 881604271,
#     'id_str': '881604271',
#     'name': 'naashonomics',
#     'screen_name': 'naashonomics',
#     'location': 'San Jose',
#     'description': 'love to win in trading #stocks and #cryptos, code for a living and trade for passion',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3388,
#     'friends_count': 4940,
#     'listed_count': 316,
#     'created_at': 'Mon Oct 15 05:13:37 +0000 2012',
#     'favourites_count': 87,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 60047,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/775828097073418240/05G6oFOI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/775828097073418240/05G6oFOI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/881604271/1563663819',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:49:45 +0000 2019',
#    'id': 1203386128117706752,
#    'id_str': '1203386128117706752',
#    'text': 'RT @ScottW_Grizzle: When your stock price has gone to outer space, nothing but perfect execution will do.\n\n$ZM revenue growth was not perfe…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'ZM', 'indices': [107, 110]}],
#     'user_mentions': [{'screen_name': 'ScottW_Grizzle',
#       'name': 'Scott Willis',
#       'id': 954022021180076032,
#       'id_str': '954022021180076032',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 951219953667137536,
#     'id_str': '951219953667137536',
#     'name': 'Grizzle',
#     'screen_name': 'grizzlemedia',
#     'location': 'Toronto, Ontario',
#     'description': 'Grizzle identifies the opportunities and risks for the new money paradigm, from a macro ‘big picture’ perspective to actionable cash-generating ideas.',
#     'url': 'https://t.co/zpmYSIRnm9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zpmYSIRnm9',
#         'expanded_url': 'http://grizzle.com',
#         'display_url': 'grizzle.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4209,
#     'friends_count': 40,
#     'listed_count': 38,
#     'created_at': 'Wed Jan 10 22:31:24 +0000 2018',
#     'favourites_count': 991,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1351,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1067373123517988870/p6MmPojt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067373123517988870/p6MmPojt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/951219953667137536/1543316667',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 05 23:54:06 +0000 2019',
#     'id': 1202737943976271872,
#     'id_str': '1202737943976271872',
#     'text': 'When your stock price has gone to outer space, nothing but perfect execution will do.\n\n$ZM revenue growth was not p… https://t.co/rWKQefr2nj',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'ZM', 'indices': [87, 90]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/rWKQefr2nj',
#        'expanded_url': 'https://twitter.com/i/web/status/1202737943976271872',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 954022021180076032,
#      'id_str': '954022021180076032',
#      'name': 'Scott Willis',
#      'screen_name': 'ScottW_Grizzle',
#      'location': '',
#      'description': 'https://t.co/qrT7sZU8H1 - The language of new money (Pot Stocks, Tech, Investing, Personal Finance) Advice for your portfolio and your wallet.',
#      'url': 'https://t.co/zpmYSIRnm9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/zpmYSIRnm9',
#          'expanded_url': 'http://grizzle.com',
#          'display_url': 'grizzle.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/qrT7sZU8H1',
#          'expanded_url': 'http://GRIZZLE.COM',
#          'display_url': 'GRIZZLE.COM',
#          'indices': [0, 23]}]}},
#      'protected': False,
#      'followers_count': 5348,
#      'friends_count': 230,
#      'listed_count': 51,
#      'created_at': 'Thu Jan 18 16:05:49 +0000 2018',
#      'favourites_count': 1747,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2512,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/994277341344907264/0LuBH2e2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/994277341344907264/0LuBH2e2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954022021180076032/1557161353',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:43:51 +0000 2019',
#    'id': 1203384643283755008,
#    'id_str': '1203384643283755008',
#    'text': 'RT @jebelfaf: Open a #trading account on #USA #option #broker #Nadex with $500 and received $200 FREE after making 5 trades.  \nhttps://t.co…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'trading', 'indices': [21, 29]},
#      {'text': 'USA', 'indices': [41, 45]},
#      {'text': 'option', 'indices': [46, 53]},
#      {'text': 'broker', 'indices': [54, 61]},
#      {'text': 'Nadex', 'indices': [62, 68]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jebelfaf',
#       'name': 'river flower',
#       'id': 1200242982294654977,
#       'id_str': '1200242982294654977',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1076429790184390656,
#     'id_str': '1076429790184390656',
#     'name': 'AdrianPaul Hoise',
#     'screen_name': 'AdrianPaulHoise',
#     'location': 'Fargo',
#     'description': 'AdrianPaul Hoise',
#     'url': 'https://t.co/HAupwJZIB3',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HAupwJZIB3',
#         'expanded_url': 'https://skepy.com/AdrianPaulHoise',
#         'display_url': 'skepy.com/AdrianPaulHoise',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 261,
#     'friends_count': 93,
#     'listed_count': 0,
#     'created_at': 'Sat Dec 22 10:50:35 +0000 2018',
#     'favourites_count': 52,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 50,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1203383623380025344/kGdvN6xe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1203383623380025344/kGdvN6xe_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076429790184390656/1575743993',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Dec 07 18:40:28 +0000 2019',
#     'id': 1203383791923810304,
#     'id_str': '1203383791923810304',
#     'text': 'Open a #trading account on #USA #option #broker #Nadex with $500 and received $200 FREE after making 5 trades.… https://t.co/Bgi3Kv0z8Y',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'trading', 'indices': [7, 15]},
#       {'text': 'USA', 'indices': [27, 31]},
#       {'text': 'option', 'indices': [32, 39]},
#       {'text': 'broker', 'indices': [40, 47]},
#       {'text': 'Nadex', 'indices': [48, 54]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Bgi3Kv0z8Y',
#        'expanded_url': 'https://twitter.com/i/web/status/1203383791923810304',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1200242982294654977,
#      'id_str': '1200242982294654977',
#      'name': 'river flower',
#      'screen_name': 'jebelfaf',
#      'location': 'USA',
#      'description': 'New things found.  Possibly mutually beneficial.  All trading involves risk.\nOr $225+ if you DM me then I can give you $25+ more after Nadex credits us the fund',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12,
#      'friends_count': 17,
#      'listed_count': 0,
#      'created_at': 'Fri Nov 29 02:40:16 +0000 2019',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1201279481006002176/_dGbGHrC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201279481006002176/_dGbGHrC_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:42:42 +0000 2019',
#    'id': 1203384352727429120,
#    'id_str': '1203384352727429120',
#    'text': 'RT @mchaudhry82: Stocks To 👀: $CHWY $MDB $SFIX $LULU $ADBE $AVGO $COST $ORCL $CRWD $HD $TREE $MET $ENPH $DAL $CNC $BA $CSCO $NFLX $PTON $WW…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'CHWY', 'indices': [30, 35]},
#      {'text': 'MDB', 'indices': [36, 40]},
#      {'text': 'SFIX', 'indices': [41, 46]},
#      {'text': 'LULU', 'indices': [47, 52]},
#      {'text': 'ADBE', 'indices': [53, 58]},
#      {'text': 'AVGO', 'indices': [59, 64]},
#      {'text': 'COST', 'indices': [65, 70]},
#      {'text': 'ORCL', 'indices': [71, 76]},
#      {'text': 'CRWD', 'indices': [77, 82]},
#      {'text': 'HD', 'indices': [83, 86]},
#      {'text': 'TREE', 'indices': [87, 92]},
#      {'text': 'MET', 'indices': [93, 97]},
#      {'text': 'ENPH', 'indices': [98, 103]},
#      {'text': 'DAL', 'indices': [104, 108]},
#      {'text': 'CNC', 'indices': [109, 113]},
#      {'text': 'BA', 'indices': [114, 117]},
#      {'text': 'CSCO', 'indices': [118, 123]},
#      {'text': 'NFLX', 'indices': [124, 129]},
#      {'text': 'PTON', 'indices': [130, 135]}],
#     'user_mentions': [{'screen_name': 'mchaudhry82',
#       'name': 'Maria Chaudhry',
#       'id': 21066148,
#       'id_str': '21066148',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 38972905,
#     'id_str': '38972905',
#     'name': 'Matthew Bigos',
#     'screen_name': 'mattbigos',
#     'location': 'Cardiff, Ca',
#     'description': 'Either playing bikes some where around the world or trading something. Probably shouldn’t follow my trading talk.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 952,
#     'friends_count': 346,
#     'listed_count': 27,
#     'created_at': 'Sun May 10 01:55:02 +0000 2009',
#     'favourites_count': 37,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 17741,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1093714642168307712/Ol813s3C_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1093714642168307712/Ol813s3C_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38972905/1479997316',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Dec 07 18:16:20 +0000 2019',
#     'id': 1203377716994695168,
#     'id_str': '1203377716994695168',
#     'text': 'Stocks To 👀: $CHWY $MDB $SFIX $LULU $ADBE $AVGO $COST $ORCL $CRWD $HD $TREE $MET $ENPH $DAL $CNC $BA $CSCO $NFLX… https://t.co/BfgArymUBG',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [{'text': 'CHWY', 'indices': [13, 18]},
#       {'text': 'MDB', 'indices': [19, 23]},
#       {'text': 'SFIX', 'indices': [24, 29]},
#       {'text': 'LULU', 'indices': [30, 35]},
#       {'text': 'ADBE', 'indices': [36, 41]},
#       {'text': 'AVGO', 'indices': [42, 47]},
#       {'text': 'COST', 'indices': [48, 53]},
#       {'text': 'ORCL', 'indices': [54, 59]},
#       {'text': 'CRWD', 'indices': [60, 65]},
#       {'text': 'HD', 'indices': [66, 69]},
#       {'text': 'TREE', 'indices': [70, 75]},
#       {'text': 'MET', 'indices': [76, 80]},
#       {'text': 'ENPH', 'indices': [81, 86]},
#       {'text': 'DAL', 'indices': [87, 91]},
#       {'text': 'CNC', 'indices': [92, 96]},
#       {'text': 'BA', 'indices': [97, 100]},
#       {'text': 'CSCO', 'indices': [101, 106]},
#       {'text': 'NFLX', 'indices': [107, 112]}],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/BfgArymUBG',
#        'expanded_url': 'https://twitter.com/i/web/status/1203377716994695168',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 21066148,
#      'id_str': '21066148',
#      'name': 'Maria Chaudhry',
#      'screen_name': 'mchaudhry82',
#      'location': 'Dallas, Texas',
#      'description': 'Options Scalper🔸Swing Trader🔸@blackboxstocks 4 The BEST Options/Stock Alerts Platform🔸Posts Are NOT Trade Recommendations🔸#BlackBoxStocks #StayGreen ⬛️💯💖',
#      'url': 'https://t.co/YlKzaRIVGx',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/YlKzaRIVGx',
#          'expanded_url': 'http://bit.ly/BlackBoxStocks2',
#          'display_url': 'bit.ly/BlackBoxStocks2',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7577,
#      'friends_count': 502,
#      'listed_count': 192,
#      'created_at': 'Tue Feb 17 05:10:23 +0000 2009',
#      'favourites_count': 18298,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 36623,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFA6C6',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3237789359/c96b8443719563d35f92d45d943641d8_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3237789359/c96b8443719563d35f92d45d943641d8_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21066148/1477710364',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': 'FFDEA6',
#      'profile_sidebar_fill_color': 'FFCAA8',
#      'profile_text_color': 'FFB2A6',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
# ...
#      {'text': 'abbv', 'indices': [82, 87]},
#      {'text': 'msft', 'indices': [88, 93]},
#      {'text': 'fb', 'indices': [94, 97]},
#      {'text': 'crm', 'indices': [98, 102]},
#      {'text': 'cmg', 'indices': [103, 107]},
#      {'text': 'pfe', 'indices': [108, 112]}],
#     'user_mentions': [{'screen_name': 'POTUS',
#       'name': 'President Trump',
#       'id': 822215679726100480,
#       'id_str': '822215679726100480',
#       'indices': [26, 32]},
#      {'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [34, 50]}],
#     'urls': [{'url': 'https://t.co/XDyMzvMto3',
#       'expanded_url': 'https://twitter.com/i/web/status/1203381583996162048',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 701988739803914242,
#     'id_str': '701988739803914242',
#     'name': 'Brian Firestone',
#     'screen_name': 'brianfires',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 849,
#     'friends_count': 222,
#     'listed_count': 21,
#     'created_at': 'Tue Feb 23 04:35:32 +0000 2016',
#     'favourites_count': 730,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 107,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/981145669992824832/I2PMDqwU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/981145669992824832/I2PMDqwU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/701988739803914242/1516438290',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1203380086902276097,
#    'quoted_status_id_str': '1203380086902276097',
#    'quoted_status': {'created_at': 'Sat Dec 07 18:25:45 +0000 2019',
#     'id': 1203380086902276097,
#     'id_str': '1203380086902276097',
#     'text': 'Suspect in deadly shooting at Florida naval base hosted a dinner party to watch mass shooting videos the night befo… https://t.co/1KWpRGqhbx',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1KWpRGqhbx',
#        'expanded_url': 'https://twitter.com/i/web/status/1203380086902276097',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.businessinsider.com" rel="nofollow">Business Insider Login</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 20562637,
#      'id_str': '20562637',
#      'name': 'Business Insider',
#      'screen_name': 'businessinsider',
#      'location': 'New York, NY',
#      'description': 'What you need to know. Follow us on Facebook, Instagram, and YouTube. Visit our home page for the top stories of the day.',
#      'url': 'https://t.co/RMkf7jACew',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RMkf7jACew',
#          'expanded_url': 'http://businessinsider.com/',
#          'display_url': 'businessinsider.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2764721,
#      'friends_count': 270,
#      'listed_count': 32090,
#      'created_at': 'Wed Feb 11 01:18:18 +0000 2009',
#      'favourites_count': 844,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 604483,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '185F7C',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1199017286780231684/P_hQmsjg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1199017286780231684/P_hQmsjg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20562637/1545063807',
#      'profile_link_color': '185F7C',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 11,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Dec 07 18:31:31 +0000 2019',
#    'id': 1203381539112800257,
#    'id_str': '1203381539112800257',
#    'text': 'RT @WallSt_Dropout: More millenials own #Bitcoin than $DIS, $NFLX, $MSFT, $BRK.  This is a pretty crazy statistic. https://t.co/DMq6QgWGCt',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [40, 48]}],
#     'symbols': [{'text': 'DIS', 'indices': [54, 58]},
#      {'text': 'NFLX', 'indices': [60, 65]},
#      {'text': 'MSFT', 'indices': [67, 72]},
#      {'text': 'BRK', 'indices': [74, 78]}],
#     'user_mentions': [{'screen_name': 'WallSt_Dropout',
#       'name': 'Wall St. Dropout',
#       'id': 950755795603423232,
#       'id_str': '950755795603423232',
#       'indices': [3, 18]}],
#     'urls': [],
#     'media': [{'id': 1202718937273769999,
#       'id_str': '1202718937273769999',
#       'indices': [115, 138],
#       'media_url': 'http://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#       'media_url_https': 'https://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#       'url': 'https://t.co/DMq6QgWGCt',
#       'display_url': 'pic.twitter.com/DMq6QgWGCt',
#       'expanded_url': 'https://twitter.com/WallSt_Dropout/status/1202718940000116737/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 677, 'h': 442, 'resize': 'fit'},
#        'large': {'w': 677, 'h': 442, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 677, 'h': 442, 'resize': 'fit'}},
#       'source_status_id': 1202718940000116737,
#       'source_status_id_str': '1202718940000116737',
#       'source_user_id': 950755795603423232,
#       'source_user_id_str': '950755795603423232'}]},
#    'extended_entities': {'media': [{'id': 1202718937273769999,
#       'id_str': '1202718937273769999',
#       'indices': [115, 138],
#       'media_url': 'http://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#       'media_url_https': 'https://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#       'url': 'https://t.co/DMq6QgWGCt',
#       'display_url': 'pic.twitter.com/DMq6QgWGCt',
#       'expanded_url': 'https://twitter.com/WallSt_Dropout/status/1202718940000116737/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 677, 'h': 442, 'resize': 'fit'},
#        'large': {'w': 677, 'h': 442, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 677, 'h': 442, 'resize': 'fit'}},
#       'source_status_id': 1202718940000116737,
#       'source_status_id_str': '1202718940000116737',
#       'source_user_id': 950755795603423232,
#       'source_user_id_str': '950755795603423232'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 969533905,
#     'id_str': '969533905',
#     'name': 'Sarah Gregory',
#     'screen_name': 'smacgregory',
#     'location': '',
#     'description': 'Known conspirator. Allegedly leads user research for Coinbase.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 53,
#     'friends_count': 128,
#     'listed_count': 0,
#     'created_at': 'Sun Nov 25 06:38:17 +0000 2012',
#     'favourites_count': 12,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 47,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1186075397634453504/kp4wZGM9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1186075397634453504/kp4wZGM9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/969533905/1571617534',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Dec 05 22:38:35 +0000 2019',
#     'id': 1202718940000116737,
#     'id_str': '1202718940000116737',
#     'text': 'More millenials own #Bitcoin than $DIS, $NFLX, $MSFT, $BRK.  This is a pretty crazy statistic. https://t.co/DMq6QgWGCt',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [20, 28]}],
#      'symbols': [{'text': 'DIS', 'indices': [34, 38]},
#       {'text': 'NFLX', 'indices': [40, 45]},
#       {'text': 'MSFT', 'indices': [47, 52]},
#       {'text': 'BRK', 'indices': [54, 58]}],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1202718937273769999,
#        'id_str': '1202718937273769999',
#        'indices': [95, 118],
#        'media_url': 'http://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#        'media_url_https': 'https://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#        'url': 'https://t.co/DMq6QgWGCt',
#        'display_url': 'pic.twitter.com/DMq6QgWGCt',
#        'expanded_url': 'https://twitter.com/WallSt_Dropout/status/1202718940000116737/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 677, 'h': 442, 'resize': 'fit'},
#         'large': {'w': 677, 'h': 442, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 677, 'h': 442, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1202718937273769999,
#        'id_str': '1202718937273769999',
#        'indices': [95, 118],
#        'media_url': 'http://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#        'media_url_https': 'https://pbs.twimg.com/media/ELDqgEzWoA8w6SY.png',
#        'url': 'https://t.co/DMq6QgWGCt',
#        'display_url': 'pic.twitter.com/DMq6QgWGCt',
#        'expanded_url': 'https://twitter.com/WallSt_Dropout/status/1202718940000116737/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 677, 'h': 442, 'resize': 'fit'},
#         'large': {'w': 677, 'h': 442, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 677, 'h': 442, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 950755795603423232,
#      'id_str': '950755795603423232',
#      'name': 'Wall St. Dropout',
#      'screen_name': 'WallSt_Dropout',
#      'location': '',
#      'description': 'Find me at my Bloomberg terminal. Nothing I tweet is investment advice.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1091,
#      'friends_count': 573,
#      'listed_count': 35,
#      'created_at': 'Tue Jan 09 15:47:00 +0000 2018',
#      'favourites_count': 4633,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1935,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1003990155777183744/PFWw91cz_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003990155777183744/PFWw91cz_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/950755795603423232/1535147460',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 242,
#     'favorite_count': 720,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 242,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.053,
#   'max_id': 1203391759503560713,
#   'max_id_str': '1203391759503560713',
#   'next_results': '?max_id=1203381539112800256&q=%24MSFT&include_entities=1',
#   'query': '%24MSFT',
#   'refresh_url': '?since_id=1203391759503560713&q=%24MSFT&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# Download latest info about ticker from Y! Finance Feed 
# https://query1.finance.yahoo.com/v7/finance/chart/MSFT?&interval=5m
import json
from urllib.request import urlopen
json.load(urlopen("https://query1.finance.yahoo.com/v7/finance/chart/MSFT?range=1h&interval=1h"))['chart']['result'][0]['meta']
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 511088400,
#  'regularMarketTime': 1574456401,
#  'gmtoffset': -18000,
#  'timezone': 'EST',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 149.59,
#  'chartPreviousClose': 149.59,
#  'previousClose': 149.48,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EST',
#    'start': 1574413200,
#    'end': 1574433000,
#    'gmtoffset': -18000},
#   'regular': {'timezone': 'EST',
#    'start': 1574433000,
#    'end': 1574456400,
#    'gmtoffset': -18000},
#   'post': {'timezone': 'EST',
#    'start': 1574456400,
#    'end': 1574470800,
#    'gmtoffset': -18000}},
#  'tradingPeriods': [[{'timezone': 'EST',
#     'start': 1574433000,
#     'end': 1574456400,
#     'gmtoffset': -18000}]],
#  'dataGranularity': '1h',
#  'range': '1h',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# Use feedparser to download and parse reuters feed for business news
# https://www.pythonforbeginners.com/feedparser/using-feedparser-in-python
# http://feeds.reuters.com/reuters/businessNews
import feedparser
d = feedparser.parse("http://feeds.reuters.com/reuters/businessNews")
print([str(l) for l in d["entries"]])
# Out:
# ['{\'title\': \'Amazon CEO says wants to work more with Pentagon\', \'title_detail\': {\'type\': \'text/plain\', \'language\': None, \'base\': \'http://feeds.reuters.com/reuters/businessNews\', \'value\': \'Amazon CEO says wants to work more with Pentagon\'}, \'summary\': \'Amazon.com Inc founder Jeff Bezos said it would support the U.S. Department of Defense as technology companies vie for more defense contracts and the Pentagon seeks to modernize itself.<div class="feedflare">\\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=3Ibru8BjLbo:S1trEh2F1pE:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=3Ibru8BjLbo:S1trEh2F1pE:V_sGLiPBpWU" border="0"></img></a>\\n</div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/3Ibru8BjLbo" height="1" width="1" alt=""/>\', \'summary_detail\': {\'type\': \'text/html\', \'language\': None, \'base\': \'http://feeds.reuters.com/reuters/businessNews\', \'value\': \'Amazon.com Inc founder Jeff Bezos said it would support the U.S. Department of Defense as technology companies vie for more defense contracts and the Pentagon seeks to modernize itself.<div class="feedflare">\\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=3Ibru8BjLbo:S1trEh2F1pE:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=3Ibru8BjLbo:S1trEh2F1pE:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=3Ibru8BjLbo:S1trEh2F1pE:V_sGLiPBpWU" border="0"></img></a>\\n</div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/3Ibru8BjLbo" height="1" width="1" alt=""/>\'}, \'links\': [{\'rel\': \'alternate\', \'type\': \'text/html\', \'href\': \'http://feeds.reuters.com/~r/reuters/businessNews/~3/3Ibru8BjLbo/amazon-ceo-says-wants-to-work-more-with-pentagon-idUSKBN1YB0JL\'}], \'link\': \'http://feeds.reuters.com/~r/reuters/businessNews/~3/3Ibru8BjLbo/amazon-ceo-says-wants-to-work-more-with-pentagon-idUSKBN1YB0JL\', \'id\': \'https://www.reuters.com/article/us-usa-pentagon-amazon/amazon-ceo-says-wants-to-work-more-with-pentagon-idUSKBN1YB0JL?feedType=RSS&feedName=businessNews\', \'guidislink\': False, \'tags\': [{\'term\': \'businessNews\', \'scheme\': None, \'label\': None}], \'published\': \'Sat, 07 Dec 2019 13:59:23 -0500\', \'published_parsed\': time.struct_time(tm_year=2019, tm_mon=12, tm_mday=7, tm_hour=18, tm_min=59, tm_sec=23, tm_wday=5, tm_yday=341, tm_isdst=0), \'feedburner_origlink\': \'https://www.reuters.com/article/us-usa-pentagon-amazon/amazon-ceo-says-wants-to-work-more-with-pentagon-idUSKBN1YB0JL?feedType=RSS&feedName=businessNews\'}', '{\'title\': "Mexico, U.S. \'getting close\' on finalizing USMCA: Mexican official", \'title_detail\': {\'type\': \'text/plain\', \'language\': None, \'base\': \'http://feeds.reuters.com/reuters/businessNews\', \'value\': "Mexico, U.S. \'getting close\' on finalizing USMCA: Mexican official"}, \'summary\': \'Mexico\\\'s deputy foreign minister for North America said on Saturday that negotiators were making progress on revisions to the United States-Mexico-Canada Agreement (USMCA) trade deal.<div class="feedflare">\\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=USUzSxMxZ0g:dhCiVHkxKec:yIl2AUoC8zA"><img src="http://feeds. ...

# %% [markdown]
# **Commands to start Kafka Cluster**
#
# https://success.docker.com/article/getting-started-with-kafka
#
# Use linux container mode (else bridging will fail for overlay network)
#
# 1. docker swarm init
# 2. docker network create -d overlay --attachable kafka-net
# 3. docker service create --network kafka-net --name=zookeeper  --publish 2181:2181 qnib/plain-zookeeper:latest
# 4. docker service create --network kafka-net --name=zkui --publish 9090:9090 qnib/plain-zkui:latest
# 5. Visit http://localhost:9090/  # Login using admin/manager
# 6. docker service create --network kafka-net --name broker --publish 9092:9092 --hostname="{{.Service.Name}}.{{.Task.Slot}}.{{.Task.ID}}" -e KAFKA_BROKER_ID={{.Task.Slot}} -e ZK_SERVERS=tasks.zookeeper qnib/plain-kafka:latest
# 7. docker ps -q --filter "label=com.docker.swarm.service.name=broker"
# 8. docker exec -t -e JMX_PORT="" f6dc03b145c0 /opt/kafka/bin/kafka-topics.sh --zookeeper tasks.zookeeper:2181 --partitions=1 --replication-factor=1 --create --topic test
# 9. docker service create --network kafka-net --name manager -e ZOOKEEPER_HOSTS=tasks.zookeeper --publish=9000:9000 qnib/plain-kafka-manager:latest
#
# http://localhost:9000/clusters/kafka
#
# OR EQUIVALENTLY
#
# https://docs.docker.com/compose/gettingstarted/
#
# 1. docker-compose up -d KafkaSetup.yml

# %%
# !pip install kafka-python
# !pip install redis

# %%
from kafka import KafkaConsumer
from json import loads

consumer = KafkaConsumer(
    'test',
     bootstrap_servers=['broker:9092'],
     api_version= (0,11),
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     #group_id='my-group',
     value_deserializer=lambda x: loads(x.decode('utf-8')))

for message in consumer:
    message = message.value
    print('{0} added'.format(message))

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer

producer = KafkaProducer(
    bootstrap_servers=['broker:9092'],
    api_version= (0,11),
    value_serializer=lambda x: dumps(x).encode('utf-8'))

for e in range(4):
    print("Processing "+str(e)+"\n")
    data = {'number' : e}
    producer.send('test', value=data)
    sleep(1)
    
producer.flush()

# %% [markdown]
# **Troubleshooting the network**
#
# https://success.docker.com/article/troubleshooting-container-networking
#
# 1. docker run -it --network container:devenv nicolaka/netshoot
# 2. lookup broker.1.c3xailkxvbttt0cdph1n303i1 [Successful]
# 3. nc -zvw2 @backend_ip <listening_port>
# 4. nslookup <IP_address>

# %%
# Troubleshooting the network

import socket
#print(socket.gethostbyname('www.google.com'))
#print(socket.gethostbyname('0410cdf71fcc')) #Succeeds now (add notebook container to the kafka-net network)
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
try:
    sock.connect(('10.0.1.73',9092))
except Exception as e:
    print("something's wrong with %s:%d. Exception is %s" % (address, port, e))
finally:
    sock.close()

# %% [markdown]
# **PySPARK Begins Here**
#
# 1. docker run -d -p 8888:8888 -v C:\Users\srmenon\Documents:/home/jovyan/work --name spark jupyter/pyspark-notebook
# 2. docker container ls
# 3. docker exec 8602565b15e7 jupyter notebook list
# 4. docker network connect kafka-net spark

# %%
# Testing spark

import pyspark
sc = pyspark.SparkContext('local[*]')

# do something to prove it works
rdd = sc.parallelize(range(1000))
rdd.takeSample(False, 5)

# %% [markdown]
# Create a consumer group to use the spark context
#
# 1. docker exec -t -e JMX_PORT="" 8cbb69e65d13 /opt/kafka/bin/kafka-console-consumer.sh --bootstrap-server broker.1.5ftnqdo6u8ee4888cazael8df:9092 --topic test --consumer-property groupd.id=test-consumer-group
# 2. start the producer above (So that data is pupmed in post the group creation)

# %%
# Connect pyspark to kafka and start stream processing
# https://spark.apache.org/docs/latest/streaming-programming-guide.html

import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[2] pyspark-shell'

import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

conf = SparkConf().set("spark.jars","/home/jovyan/work/spark-streaming-kafka-0-8-assembly_2.11-2.4.4.jar")
print(conf.toDebugString())
sc = SparkContext(conf=conf)
sc.setLogLevel("WARN")
ssc = StreamingContext(sc,60)
kafkaStream = KafkaUtils.createStream(
    ssc=ssc, 
    zkQuorum='zookeeper:2181', 
    groupId='test-consumer-group',#, #Consumer Group 
    topics={'test':1})
lines = kafkaStream.map(lambda x: x[1])
lines.pprint()
ssc.start()  
print("Going to wait termination")
ssc.awaitTermination()

# %% [markdown]
# **Tensorflow Model Serving with Docker**
#
# https://www.tensorflow.org/tfx/serving/docker
#
# Running an instance of TSX Server
# 1. docker pull tensorflow/serving
# 2. git clone https://github.com/tensorflow/serving
# 3. docker run -t --rm -p 8501:8501 -v "C:\Users\srmenon\Documents\Jarvis\serving\tensorflow_serving\servables\tensorflow\testdata\saved_model_half_plus_two_cpu:/models/half_plus_two" -e MODEL_NAME=half_plus_two  tensorflow/serving &
# 4. curl -d "{\"instances\": [1.0, 2.0, 5.0]}" -g -X POST http://localhost:8501/v1/models/half_plus_two:predict
# 5. docker network connect kafka-net xenodochial_tesla

# %%
# PySpark Code to call TSX
import requests
r = requests.post(
    "http://10.0.1.48:8501/v1/models/half_plus_two:predict",
    "{\"instances\": [1.0, 2.0, 5.0]}")
# Am able to reach the server using ip address - but name resolution is failing
print(r.text)

# %%
# PySpark streaming from Kafka with calls to TSX
# DStream transformations : http://sungsoo.github.io/2015/04/06/transformations-on-dstreams.html

import os
import requests
import json

os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[2] pyspark-shell'

import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

conf = SparkConf().set("spark.jars","/home/jovyan/work/spark-streaming-kafka-0-8-assembly_2.11-2.4.4.jar")
print(conf.toDebugString())
sc = SparkContext(conf=conf)
sc.setLogLevel("WARN")
ssc = StreamingContext(sc,60) # 60 is the batch interval :)
kafkaStream = KafkaUtils.createStream(
    ssc=ssc, 
    zkQuorum='zookeeper:2181', 
    groupId='test-consumer-group',#, #Consumer Group 
    topics={'test':1})
lines = kafkaStream.map(lambda x: x[1])
lines.pprint()
lines = lines.map(lambda a: str(json.loads(a)["number"]))
lines.pprint()
lines = lines.reduce(lambda v,agg: agg+", "+v)
lines.pprint()
lines = lines.map(lambda a: requests.post(
        "http://10.0.1.48:8501/v1/models/half_plus_two:predict",
        "{\"instances\": ["+a+"]}").text)
lines.pprint()
ssc.start()  
print("Going to wait termination")
ssc.awaitTermination()

# %% [markdown]
# **Setup Redis Image and DB**
#
# https://koukia.ca/installing-redis-on-windows-using-docker-containers-7737d2ebc25e
# https://github.com/MicrosoftArchive/redis/releases
#
# 1. docker pull redis
# 2. docker run --name redis-store -d redis
# 3. docker network connect kafka-net redis-store
# 4. goto C:\Program Files\Redis
# 5. redis-cli -h localhost/127.0.0.1 -p 6379
# 6. set key value
# 7. get key

# %%
# Write to Redis from Python
# !pip install redis
import redis
r = redis.StrictRedis(host = 'redis-store', port = 6379)
r.set("Sreedal",1020)
print(r.get("171.5"))

# %%
# Write to Redis from within PySpark context

import os
import requests
import json
import redis

os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[2] pyspark-shell'

import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

def SetVal(x):
    r = redis.StrictRedis(host = 'redis-store', port = 6379)
    r.set(x,int(x))

conf = SparkConf().set("spark.jars","/home/jovyan/work/spark-streaming-kafka-0-8-assembly_2.11-2.4.4.jar")
print(conf.toDebugString())
sc = SparkContext(conf=conf)
sc.setLogLevel("WARN")
ssc = StreamingContext(sc,60) # 60 is the batch interval :)
kafkaStream = KafkaUtils.createStream(
    ssc=ssc, 
    zkQuorum='zookeeper:2181', 
    groupId='test-consumer-group',#, #Consumer Group 
    topics={'test':1})
lines = kafkaStream.map(lambda x: x[1])
lines.pprint()
lines = lines.map(lambda a: str(json.loads(a)["number"]))
lines.pprint()
lines = lines.reduce(lambda v,agg: agg+", "+v)
lines.pprint()
lines = lines.map(lambda a: requests.post(
        "http://serving:8501/v1/models/half_plus_two:predict",
        "{\"instances\": ["+a+"]}").text)
lines.pprint()
lines = lines.flatMap(lambda x: json.loads(x)["predictions"])
lines.pprint()
lines = lines.map(lambda x: SetVal(x))
lines.pprint()

ssc.start()  
print("Going to wait termination")
ssc.awaitTermination()

# %% [markdown]
# **Node Provisioning and Web App with Redis Read and pretty print list**
#
# https://nodejs.org/en/docs/guides/nodejs-docker-webapp/
#
# 1. cd NodeApp
# 2. docker build -t sreedal/jarvis-node .
# 3. docker push sreedal/jarvis-node
# 4. docker run -p 49160:8080 -d sreedal/jarvis-node
# 5. docker network connect kafka-net codescending_edison

# %%
import redis
r = redis.StrictRedis(host = 'redis-store', port = 6379)
r.set('LatestNews',str("Sreedal"))
# Out:
# True
