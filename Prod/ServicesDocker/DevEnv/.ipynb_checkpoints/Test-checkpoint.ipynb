# %%
# !pip install twitter
# !pip install feedparser
# !pip install schedule
# !pip install kafka-python
# !pip install redis
# !pip install uuid
# Out:
# Requirement already satisfied: twitter in /opt/conda/lib/python3.7/site-packages (1.18.0)
# Requirement already satisfied: feedparser in /opt/conda/lib/python3.7/site-packages (5.2.1)
# Requirement already satisfied: schedule in /opt/conda/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.7/site-packages (1.4.7)
# Requirement already satisfied: redis in /opt/conda/lib/python3.7/site-packages (3.3.11)
# Requirement already satisfied: uuid in /opt/conda/lib/python3.7/site-packages (1.30)

# %%
from time import sleep
from json import dumps, loads, load
from kafka import KafkaProducer
from datetime import datetime, timedelta
from pytz import timezone
from feedparser import parse
from urllib.request import urlopen
from twitter import Twitter
import schedule
from datetime import datetime
import uuid

# %%
tickers = ["MSFT","AAPL"]
feeds = ["http://feeds.reuters.com/reuters/businessNews",
         "https://finance.yahoo.com/news/rssindex/", 
         "https://www.nasdaq.com/feed/rssoutbound",
         "https://news.microsoft.com/feed",
        "https://feeds.a.dj.com/rss/WSJcomUSBusiness.xml",
        "https://feeds.a.dj.com/rss/RSSMarketsMain.xml",
        "http://www.marketwatch.com/rss/topstories",
        "http://www.marketwatch.com/rss/marketpulse",
        "http://www.marketwatch.com/rss/realtimeheadlines",
        "http://feeds.marketwatch.com/marketwatch/bulletins",
        "https://www.cnbc.com/id/10000664/device/rss/rss.html",
        "https://www.cnbc.com/id/10001147/device/rss/rss.html",
        "http://feeds.feedburner.com/TechCrunch/",
        "https://www.ft.com/?format=rss",
        "https://rss.nytimes.com/services/xml/rss/nyt/Business.xml",
        "https://abcnews.go.com/abcnews/moneyheadlines",
        "https://www.cbsnews.com/latest/rss/main",
        "https://markets.businessinsider.com/rss/news",
        "http://newsrss.bbc.co.uk/rss/newsonline_uk_edition/front_page/rss.xml",
        "http://feeds.bbci.co.uk/news/business/rss.xml",
        ]
yfeeds = []

producer = KafkaProducer(
    bootstrap_servers=['broker:9092'],
    api_version= (0,11),
    value_serializer=lambda x: dumps(x).encode('utf-8'))

# Authenticate with Twitter & search
# https://pypi.org/project/twitter/
# https://developer.twitter.com/en/apps/17019807
from twitter import *
t = Twitter(auth=OAuth(consumer_key="nDwKHutvaskyGecZkCS1SiYY8", consumer_secret="zlQdJIuFUGGglbMO2kYMk6oNLFztzipxhRANNz5q5gqfn1tGb1", token="73568030-GqfoqkfWRhqhARS9uzz51vg1UGSV7AGRaOxDkAurZ", token_secret="1kiHGfyDfO7gcaJbGFnr3lnLA3vXc8ti9hJhj1lnTTvEm"))

# %%
last_time_step = datetime.now(tz=timezone('US/Pacific'))-timedelta(days=3)
import pandas as pd
feed_data = {}
for feed in feeds:
    try:
        feed_data[feed] = [{"Type": "News", "Timestamp": datetime.timestamp(pd.to_datetime(l.published)), "Title":l.title, "Summary":l.summary, "Link":l.link} for l in (parse(feed))["entries"] if pd.to_datetime(l.published )>last_time_step]
    except TypeError:
        print("TypeError")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/feedparser.py in __getattr__(self, key)
#     397         try:
# --> 398             return self.__getitem__(key)
#     399         except KeyError:
#
# /opt/conda/lib/python3.7/site-packages/feedparser.py in __getitem__(self, key)
#     355                 return dict.__getitem__(self, realkey)
# --> 356         return dict.__getitem__(self, key)
#     357
#
# KeyError: 'summary'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-21d45c3fe6f8> in <module>
#       4 for feed in feeds:
#       5     try:
# ----> 6         feed_data[feed] = [{"Type": "News", "Timestamp": datetime.timestamp(pd.to_datetime(l.published)), "Title":l.title, "Summary":l.summary, "Link":l.link} for l in (parse(feed))["entries"] if pd.to_datetime(l.published )>last_time_step]
#       7     except TypeError:
#       8         print("TypeError")
#
# <ipython-input-4-21d45c3fe6f8> in <listcomp>(.0)
#       4 for feed in feeds:
#       5     try:
# ----> 6         feed_data[feed] = [{"Type": "News", "Timestamp": datetime.timestamp(pd.to_datetime(l.published)), "Title":l.title, "Summary":l.summary, "Link":l.link} for l in (parse(feed))["entries"] if pd.to_datetime(l.published )>last_time_step]
#       7     except TypeError:
#       8         print("TypeError")
#
# /opt/conda/lib/python3.7/site-packages/feedparser.py in __getattr__(self, key)
#     398             return self.__getitem__(key)
#     399         except KeyError:
# --> 400             raise AttributeError("object has no attribute '%s'" % key)
#     401
#     402     def __hash__(self):
#
# AttributeError: object has no attribute 'summary'

# %%
for feed in feeds:
    print(f'{len(feed_data[feed])} from {feed}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cd991d994c4e> in <module>
#       1 for feed in feeds:
# ----> 2     print(f'{len(feed_data[feed])} from {feed}')
#
# NameError: name 'feed_data' is not defined

# %%
parse("https://finance.yahoo.com/news/rssindex/")
# Out:
# {'feed': {'title': 'Yahoo Finance',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://finance.yahoo.com/news/rssindex/',
#    'value': 'Yahoo Finance'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://finance.yahoo.com/'}],
#   'link': 'https://finance.yahoo.com/',
#   'subtitle': 'At Yahoo Finance, you get free stock quotes, up-to-date news, portfolio management resources, international market data, social interaction and mortgage rates that help you manage your financial life.',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://finance.yahoo.com/news/rssindex/',
#    'value': 'At Yahoo Finance, you get free stock quotes, up-to-date news, portfolio management resources, international market data, social interaction and mortgage rates that help you manage your financial life.'},
#   'language': 'en-US',
#   'rights': 'Copyright (c) 2020 Yahoo! Inc. All rights reserved',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://finance.yahoo.com/news/rssindex/',
#    'value': 'Copyright (c) 2020 Yahoo! Inc. All rights reserved'},
#   'published': 'Sun, 23 Feb 2020 19:19:30 -0500',
#   'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=24, tm_hour=0, tm_min=19, tm_sec=30, tm_wday=0, tm_yday=55, tm_isdst=0),
#   'ttl': '5',
#   'image': {'title': 'Yahoo Finance',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Yahoo Finance'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/'}],
#    'link': 'https://finance.yahoo.com/',
#    'href': 'https://s.yimg.com/zz/nn/lib/metro/g/my/yahoo_en-US_f_p_190x45_2x.png'}},
#  'entries': [{'title': 'Here&#39;s what smart investors do with their 401(k)s when the stock market is hitting highs',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Here&#39;s what smart investors do with their 401(k)s when the stock market is hitting highs'},
#    'summary': '<p><a href="https://finance.yahoo.com/news/heres-smart-investors-401-k-143548351.html"><img src="http://l2.yimg.com/uu/api/res/1.2/oQG6M9yD.OvFGTBDFMd9ag--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-
13 about weakening earnings exposed just how much China’s most valuable company depends on old-fashioned elbow grease in delivery, manufacturing and logistics. The e-commerce giant warned of a “significant” hit this quarter because the people who take orders, fabricate products and then ship them to doorsteps can’t get to their jobs. It’s a reminder of how much the fortunes of China’s tech giants hinge on unglamorous, analog tasks -- at their peak, Alibaba’s partners deliver upwards of a billion packages a day.“We just have fewer delivery people now because my co-workers couldn’t get back to work,” said a courier for Alibaba partner SF Express who would only give his surname as Qiu before dashing off. “Those of us still working are assigned more packages. Good thing I got a break during the Spring Festival,” he said, referring to the Lunar New Year holidays.Read more Alibaba Warns Virus Having Broad Impact on Chinese EconomyRead more: Chinese Abandon Food Delivery Fearing Drivers Will Spread VirusChina’s corporations are struggling to cope with the coronavirus outbreak to varying degrees. Some such as Tencent and TikTok-owner ByteDance are benefiting from a vastly increased audience as millions are confined to their homes, with mobile gaming and livestreaming their only recourse to entertainment. Tencent, which reports earnings in March, is expected to unveil a surge in time spent on games such as Honor of Kings and growth on WeChat. For now, analysts are projecting its fastest pace of sales growth since 2018 in both the December and March quarters.But few in tech offer as broad a glimpse into business under the epidemic than Alibaba. The company initially benefited from a surge in online shopping from millions confined by the largest work-from-home undertaking in history. Yet, it turns out, a lot of the millions of packages that get delivered every day are cheap items such as groceries and face masks. Consumers are eschewing pricier merchandise given growing fears that the eventual hit to the Chinese economy could be far worse than expected.“Logistics is probably the biggest bottleneck right now, but it is improving. However, it is not the only bottleneck,” said Jerry Liu, a Hong Kong-based analyst with UBS who expects things to get back to normal only around the second half. “We do assume weaker demand for e-commerce platforms even if online penetration is higher in recent weeks. Based on our checks, a part of that is due to l ...
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/virus-outbreak-exposes-46-billion-210000098.html'}],
#    'link': 'https://finance.yahoo.com/news/virus-outbreak-exposes-46-billion-210000098.html',
#    'published': 'Sun, 23 Feb 2020 16:00:00 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'https://www.bloomberg.com/', 'title': 'Bloomberg'},
#    'id': 'virus-outbreak-exposes-46-billion-210000098.html',
#    'guidislink': False,
#    'media_content': [{'height': '86',
#      'url': 'http://l1.yimg.com/uu/api/res/1.2/1IjhsGbYqyGk62leqzHpxQ--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/bloomberg_technology_68/6aec7a9a8566103b853a3191407f423f',
#      'width': '130'}],
#    'media_text': {'type': 'html'},
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'Top Insider Buys Highlight for the Week of Feb. 21',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Top Insider Buys Highlight for the Week of Feb. 21'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/top-insider-buys-highlight-week-210815176.html'}],
#    'link': 'https://finance.yahoo.com/news/top-insider-buys-highlight-week-210815176.html',
#    'published': 'Sun, 23 Feb 2020 16:08:15 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=21, tm_min=8, tm_sec=15, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'http://www.gurufocus.com/', 'title': 'GuruFocus.com'},
#    'id': 'top-insider-buys-highlight-week-210815176.html',
#    'guidislink': False,
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'Coronavirus, consumer sentiment, GDP, retail earnings: What to know in the week ahead',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Coronavirus, consumer sentiment, GDP, retail earnings: What to know in the week ahead'},
#    'summary': '<p><a href="https://finance.yahoo.com/news/coronavirus-consumer-sentiment-gdp-retail-earnings-what-to-know-in-the-week-ahead-212252607.html"><img src="http://l2.yimg.com/uu/api/res/1.2/VHGp9EMuvw6qRaxbzzejLA--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-02
tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'https://www.bloomberg.com/', 'title': 'Bloomberg'},
#    'id': 'tesla-rival-sets-banish-160-040000922.html',
#    'guidislink': False,
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': '3 Monster Growth Stocks Primed for Further Gains',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': '3 Monster Growth Stocks Primed for Further Gains'},
#    'summary': '<p><a href="https://finance.yahoo.com/news/3-monster-growth-stocks-primed-121020345.html"><img src="http://l.yimg.com/uu/api/res/1.2/DjGzrev5mSc0uH7QvDSLyQ--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en-US/tipranks_452/931c733fdaf5fc8e22a80a31ff0ec1a5" width="130" height="86" alt="3 Monster Growth Stocks Primed for Further Gains" align="left" title="3 Monster Growth Stocks Primed for Further Gains" border="0" ></a>When it comes down to it, investors are focused on a single factor: a stock’s ability to deliver returns. As Wall Street observers gauge the strength of a particular investment opportunity, often, they will filter out the noise and instead, concentrate their attention on its long-term growth prospects. We are referring to whether or not a name can achieve sustainable growth over the long haul, handsomely rewarding investors in the years to come.So, with this goal in mind, what’s the first step for investors ready to get down to business? It’s narrowing down the multitude of tickers traded in the public market to a select few that represent the pick of the bunch. To make it into this exclusive group, these names should not only have strong long-term growth narratives, but also the analyst community’s support.Setting out on our own search, we used TipRanks’ Stock Screener tool to pinpoint 3 stocks that have earned “Strong Buy” consensus ratings from the analysts and boast substantial upside potential from current levels.Let’s get started.Selecta Biosciences (SELB)Selecta Biosciences believes that its ImmTOR immune tolerance platform can help patients fight rare diseases. Currently, biologic drugs can trigger neutralizing antibodies (NAbs) that work against the therapy, but ImmTOR technology allows for immune tolerance of the therapy. With this biotech already having gained 107% over the last twelve months, investors want to know if there’s more fuel left in the tank.According to Mizuho Securities analyst Difei Yang, the answer is yes. She highlights the COMPARE trial as being the driving force behind her bullish thesis. The Phase 2 clinical trial is evaluating its lead candidate, SEL-212, in patients with chronic refractory gout, specifically looking at its efficacy in resolving symptoms like flares and gouty arthritis. Based on earlier clinical data, a combined therapy of ImmTOR and pegadricase, the current uricase therapy approved by the FDA, was able to reduce the occurrence of gout flares. As a result, the data allowed SEL-212 to proceed to a head-to-head COMPARE trial, the enrollment of which was completed back in December.Yang argues that the “encouraging” interim data increases the therapy’s likelihood of FDA approval. When looking at the big picture, she is optimistic about the platform as it may lead to a re-dosing of gene therapy. Additionally, she points out that the company was able to cut its financing overhang.Given Yang’s high hopes for SELB, it makes sense that she stayed with the bulls. Not only did she maintain a Buy rating, but she also bumped up the price target from $4 to $7. This new target conveys her confidence in the biotech’s ability to climb 66% higher over the next year. (To watch Yang’s track record, click here)What does the rest of the Street have to say? As it turns out, when it comes to SELB, other analysts are also on board. With 5 Buy ratings assigned in the last three months compared to no Holds or Sells, the word on the Street is that the stock is a Strong Buy. Not to mention the $8.67 average price target puts the potential twelve-month gain at 105%. (See Selecta stock analysis on TipRanks) Ocular Therapeutix (OCUL)This biopharma uses a hydrogel platform to develop innovative treatments for various eye diseases. While its DEXTENZA insert has received FDA approval for the treatment of inflammation and pain following ophthalmic surgery, analysts point to its development pipeline as being capable of driving further growth on top of its already posted 5 ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
# ...
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/dont-race-buy-dow-inc-133534990.html'}],
#    'link': 'https://finance.yahoo.com/news/dont-race-buy-dow-inc-133534990.html',
#    'published': 'Sat, 22 Feb 2020 08:35:34 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday
/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-02/0cf05b10-5637-11ea-b777-ba9079cbe1ff" width="130" height="86" alt="CNN and other outlets are in Donald Trump&#39;s &#39;crosshairs&#39;: WarnerMedia CEO" align="left" title="CNN and other outlets are in Donald Trump&#39;s &#39;crosshairs&#39;: WarnerMedia CEO" border="0" ></a>President Donald Trump doesn’t have a vendetta against CNN — he has one against all media outlets that do adversarial coverage, says John Stankey, who oversees CNN in his role as WarnerMedia CEO.<p><br clear="all">'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/cnn-other-outlets-trumps-crosshairs-warner-media-ceo-122708254.html'}],
#    'link': 'https://finance.yahoo.com/news/cnn-other-outlets-trumps-crosshairs-warner-media-ceo-122708254.html',
#    'published': 'Sun, 23 Feb 2020 07:27:08 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=12, tm_min=27, tm_sec=8, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'http://finance.yahoo.com/', 'title': 'Yahoo Finance'},
#    'id': 'cnn-other-outlets-trumps-crosshairs-warner-media-ceo-122708254.html',
#    'guidislink': False,
#    'media_content': [{'height': '86',
#      'url': 'http://l1.yimg.com/uu/api/res/1.2/sqXeR8KnbQht5_LLOSqe6A--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-02/0cf05b10-5637-11ea-b777-ba9079cbe1ff',
#      'width': '130'}],
#    'media_text': {'type': 'html'},
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'Intuit Nears Deal to Buy Credit Karma for $7 Billion: WSJ',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Intuit Nears Deal to Buy Credit Karma for $7 Billion: WSJ'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/intuit-nears-deal-buy-credit-055044610.html'}],
#    'link': 'https://finance.yahoo.com/news/intuit-nears-deal-buy-credit-055044610.html',
#    'published': 'Sun, 23 Feb 2020 10:18:42 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=15, tm_min=18, tm_sec=42, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'https://www.bloomberg.com/', 'title': 'Bloomberg'},
#    'id': 'intuit-nears-deal-buy-credit-055044610.html',
#    'guidislink': False,
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'UAE’s Latest Natural Gas Discovery Is A Gamechanger',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'UAE’s Latest Natural Gas Discovery Is A Gamechanger'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/uae-latest-natural-gas-discovery-200000751.html'}],
#    'link': 'https://finance.yahoo.com/news/uae-latest-natural-gas-discovery-200000751.html',
#    'published': 'Sun, 23 Feb 2020 15:00:00 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'http://oilprice.com', 'title': 'Oilprice.com'},
#    'id': 'uae-latest-natural-gas-discovery-200000751.html',
#    'guidislink': False,
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think'},
#    'summary': '<p><a href="https://finance.yahoo.com/news/puma-biotechnology-inc-just-released-144340474.html"><img src="http://l1.yimg.com/uu/api/res/1.2/O8Ty_ycIODufv7fhs8k8Pg--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/b5988ca679c7c826c911cdff7e4e996f" width="130" height="86" alt="Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think" align="left" title="Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think" border="0" ></a>Shareholders of Puma Biotechnology, Inc. (NASDAQ:PBYI) will be pleased this week, given that the stock price is up 11...<p><br clear="all">',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': '<p><a href="https://finance.yahoo.com/news/puma-biotechnology-inc-just-released-144340474.html"><img src="http://l1.yimg.com/uu/api/res/1.2/O8Ty_ycIODufv7fhs8k8Pg--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/b5988ca679c7c826c911cdff7e4e996f" width="130" height="86" alt="Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think" align="left" title="Puma Biotechnology, Inc. Just Released Its Yearly Earnings: Here&#39;s What Analysts Think" border="0" ></a>Shareholders of Puma Biotechnology, Inc. (NASDAQ:PBYI) will be pleased this week, given that the stock price is up 11...<p><br clear="all">'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/puma-biotechnology-inc-just-released-144340474.html'}],
#    'link': 'https://finance.yahoo.com/news/puma-biotechnology-inc-just-released-144340474.html',
#    'published': 'Sun, 23 Feb 2020 09:43:40 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=23, tm_hour=14, tm_min=43, tm_sec=40, tm_wday=6, tm_yday=54, tm_isdst=0),
#    'source': {'href': 'https://simplywall.st/', 'title': 'Simply Wall St.'},
#    'id': 'puma-biotechnology-inc-just-released-144340474.html',
#    'guidislink': False,
#    'media_content': [{'height': '86',
#      'url': 'http://l1.yimg.com/uu/api/res/1.2/O8Ty_ycIODufv7fhs8k8Pg--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/b5988ca679c7c826c911cdff7e4e996f',
#      'width': '130'}],
#    'media_text': {'type': 'html'},
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''},
#   {'title': 'Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks',
#    'title_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': 'Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks'},
#    'summary': '<p><a href="https://finance.yahoo.com/news/dont-buy-dominion-energy-inc-132308871.html"><img src="http://l2.yimg.com/uu/api/res/1.2/Ru8KJN1foHN4H6HlTU2X7g--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/6f447787aaeb55c143f471d3a3900528" width="130" height="86" alt="Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks" align="left" title="Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks" border="0" ></a>Dominion Energy, Inc. (NYSE:D) stock is about to trade ex-dividend in 4 days time. You will need to purchase shares...<p><br clear="all">',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://finance.yahoo.com/news/rssindex/',
#     'value': '<p><a href="https://finance.yahoo.com/news/dont-buy-dominion-energy-inc-132308871.html"><img src="http://l2.yimg.com/uu/api/res/1.2/Ru8KJN1foHN4H6HlTU2X7g--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/6f447787aaeb55c143f471d3a3900528" width="130" height="86" alt="Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks" align="left" title="Don&#39;t Buy Dominion Energy, Inc. (NYSE:D) For Its Next Dividend Without Doing These Checks" border="0" ></a>Dominion Energy, Inc. (NYSE:D) stock is about to trade ex-dividend in 4 days time. You will need to purchase shares...<p><br clear="all">'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://finance.yahoo.com/news/dont-buy-dominion-energy-inc-132308871.html'}],
#    'link': 'https://finance.yahoo.com/news/dont-buy-dominion-energy-inc-132308871.html',
#    'published': 'Sat, 22 Feb 2020 08:23:08 -0500',
#    'published_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=22, tm_hour=13, tm_min=23, tm_sec=8, tm_wday=5, tm_yday=53, tm_isdst=0),
#    'source': {'href': 'https://simplywall.st/', 'title': 'Simply Wall St.'},
#    'id': 'dont-buy-dominion-energy-inc-132308871.html',
#    'guidislink': False,
#    'media_content': [{'height': '86',
#      'url': 'http://l2.yimg.com/uu/api/res/1.2/Ru8KJN1foHN4H6HlTU2X7g--/YXBwaWQ9eXRhY2h5b247aD04Njt3PTEzMDs-/https://media.zenfs.com/en/simply_wall_st__316/6f447787aaeb55c143f471d3a3900528',
#      'width': '130'}],
#    'media_text': {'type': 'html'},
#    'media_credit': [{'role': 'publishing company'}],
#    'credit': ''}],
#  'bozo': 0,
#  'headers': {'x-amz-id-2': 'td6+ZIpSTmWdmneHqd2/yQH0jC+NzkAiX6rRRtW1v6tAEJ+V6W+X+a2ldG+eRl6oMU7XACnk5eY=',
#   'x-amz-request-id': '7FCAE06BF0A99FD2',
#   'Date': 'Mon, 24 Feb 2020 00:23:15 GMT',
#   'Last-Modified': 'Mon, 24 Feb 2020 00:19:32 GMT',
#   'ETag': '"7b3e038c7f881579d1e90eec89f81b0b"',
#   'x-amz-server-side-encryption': 'AES256',
#   'Cache-Control': 'public, max-age=600',
#   'Accept-Ranges': 'bytes',
#   'Content-Type': 'application/xml',
#   'Content-Length': '212071',
#   'Server': 'ATS',
#   'Referrer-Policy': 'no-referrer-when-downgrade',
#   'Vary': 'Origin',
#   'Age': '283',
#   'Strict-Transport-Security': 'max-age=15552000',
#   'X-Frame-Options': 'SAMEORIGIN',
#   'Connection': 'close',
#   'Expect-CT': 'max-age=31536000, report-uri="http://csp.yahoo.com/beacon/csp?src=yahoocom-expect-ct-report-only"',
#   'X-XSS-Protection': '1; mode=block',
#   'X-Content-Type-Options': 'nosniff'},
#  'etag': '"7b3e038c7f881579d1e90eec89f81b0b"',
#  'updated': 'Mon, 24 Feb 2020 00:19:32 GMT',
#  'updated_parsed': time.struct_time(tm_year=2020, tm_mon=2, tm_mday=24, tm_hour=0, tm_min=19, tm_sec=32, tm_wday=0, tm_yday=55, tm_isdst=0),
#  'href': 'https://finance.yahoo.com/news/rssindex/',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'media': 'http://search.yahoo.com/mrss/'}}

# %%
feed_data["https://news.microsoft.com/feed"]
# Out:
# [{'Type': 'News',
#   'Timestamp': 1576868416.0,
#   'Title': 'Microsoft and KKBOX Group launch global strategic partnership',
#   'Summary': '<p>TAIPEI — December 20, 2019 — Microsoft Taiwan and Asia’s leading media technology company, KKBOX Group, jointly announced today the launch of a global strategic partnership that will migrate the group’s subsidiary KKBOX’s music streaming services to the Microsoft Azure cloud platform. Additionally, KKBOX Group subsidiary KKStream has joined Microsoft’s global partner network to release <span aria-label="ellipsis">[…]</span></p>\n<p>The post <a rel="nofollow" href="https://news.microsoft.com/2019/12/20/microsoft-and-kkbox-group-launch-global-strategic-partnership/">Microsoft and KKBOX Group launch global strategic partnership</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://news.microsoft.com/2019/12/20/microsoft-and-kkbox-group-launch-global-strategic-partnership/'},
#  {'Type': 'News',
#   'Timestamp': 1576850355.0,
#   'Title': 'The chassis of the future is code: ZF collaborates with Microsoft to become a provider of software solutions',
#   'Summary': '<p>The post <a rel="nofollow" href="https://press.zf.com/press/en/releases/release_14016.html">The chassis of the future is code: ZF collaborates with Microsoft to become a provider of software solutions</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://press.zf.com/press/en/releases/release_14016.html'},
#  {'Type': 'News',
#   'Timestamp': 1576850159.0,
#   'Title': 'Ericsson and Microsoft team up for the next generation of connected cars',
#   'Summary': '<p>The post <a rel="nofollow" href="https://www.ericsson.com/en/press-releases/2019/12/ericsson-and-microsoft-team-up-for-the-next-generation-of-connected-cars">Ericsson and Microsoft team up for the next generation of connected cars</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://www.ericsson.com/en/press-releases/2019/12/ericsson-and-microsoft-team-up-for-the-next-generation-of-connected-cars'},
#  {'Type': 'News',
#   'Timestamp': 1576808572.0,
#   'Title': 'Last minute US holiday deals available now at Microsoft Store',
#   'Summary': '<p>The post <a rel="nofollow" href="https://blogs.windows.com/windowsexperience/2019/12/19/procrastinators-rejoice-last-minute-us-holiday-deals-available-now-at-microsoft-store/">Last minute US holiday deals available now at Microsoft Store</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://blogs.windows.com/windowsexperience/2019/12/19/procrastinators-rejoice-last-minute-us-holiday-deals-available-now-at-microsoft-store/'},
#  {'Type': 'News',
#   'Timestamp': 1576770982.0,
#   'Title': 'Dawn of a decade: The top 10 tech policy issues for the 2020s',
#   'Summary': '<p>The post <a rel="nofollow" href="https://www.linkedin.com/pulse/dawn-decade-top-ten-tech-policy-issues-2020s-brad-smith/">Dawn of a decade: The top 10 tech policy issues for the 2020s</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://www.linkedin.com/pulse/dawn-decade-top-ten-tech-policy-issues-2020s-brad-smith/'},
#  {'Type': 'News',
#   'Timestamp': 1576770090.0,
#   'Title': 'How tech intensity accelerates business value',
#   'Summary': '<p>The post <a rel="nofollow" href="https://cloudblogs.microsoft.com/industry-blog/manufacturing/2019/12/18/how-technology-intensity-accelerates-business-value/">How tech intensity accelerates business value</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://cloudblogs.microsoft.com/industry-blog/manufacturing/2019/12/18/how-technology-intensity-accelerates-business-value/'},
#  {'Type': 'News',
#   'Timestamp': 1576769792.0,
#   'Title': 'Developing a quantum computing-ready global workforce',
#   'Summary': '<p>The post <a rel="nofollow" href="https://cloudblogs.microsoft.com/quantum/2019/12/18/quantum-ready-global-workforce-microsoft-universities/">Developing a quantum computing-ready global workforce</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://cloudblogs.microsoft.com/quantum/2019/12/18/quantum-ready-global-workforce-microsoft-universities/'},
#  {'Type': 'News',
#   'Timestamp': 1576695797.0,
#   'Title': 'Parents: New video helps you get up to speed on gaming controls before the holidays',
#   'Summary': '<p>The post <a rel="nofollow" href="https://news.xbox.com/en-us/2019/12/18/xbox-shares-the-must-know-holiday-gaming-tips-for-parents/">Parents: New video helps you get up to speed on gaming controls before the holidays</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://news.xbox.com/en-us/2019/12/18/xbox-shares-the-must-know-holiday-gaming-tips-for-parents/'},
#  {'Type': 'News',
#   'Timestamp': 1576691804.0,
#   'Title': '10 people who inspired CEO Satya Nadella this year',
#   'Summary': '<p>The post <a rel="nofollow" href="https://www.linkedin.com/posts/satyanadella_one-of-the-great-privileges-of-my-job-is-activity-6613120670765326336-3xdF">10 people who inspired CEO Satya Nadella this year</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://www.linkedin.com/posts/satyanadella_one-of-the-great-privileges-of-my-job-is-activity-6613120670765326336-3xdF'},
#  {'Type': 'News',
#   'Timestamp': 1576688481.0,
#   'Title': 'How architects visualized design for world’s biggest airport',
#   'Summary': '<p>The post <a rel="nofollow" href="https://news.microsoft.com/?p=435574">How architects visualized design for world’s biggest airport</a> appeared first on <a rel="nofollow" href="https://news.microsoft.com">Stories</a>.</p>',
#   'Link': 'https://news.microsoft.com/?p=435574'}]

# %%
len([entry['Title'] for feed in feeds for entry in feed_data[feed]])
# Out:
# 133

# %%
output = set()
for x in [entry['Summary'] for feed in feeds for entry in feed_data[feed]]:
    output.add(x)
print(len(output))
# Out:
# 131

# %%
print(list(output)[1].encode("utf8"))
# Out:
# b'Britain has approved the purchase of British defense company Cobham  by U.S. investor Advent International for $5 billion after the private equity group made commitments to address national security concerns.<div class="feedflare">\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=1u0qnwpZWWk:-1yc_poI31E:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=1u0qnwpZWWk:-1yc_poI31E:V_sGLiPBpWU" border="0"></img></a>\n</div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/1u0qnwpZWWk" height="1" width="1" alt=""/>'

# %%
str(list(output)[1].encode("utf8"))
# Out:
# 'b\'Britain has approved the purchase of British defense company Cobham  by U.S. investor Advent International for $5 billion after the private equity group made commitments to address national security concerns.<div class="feedflare">\\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=1u0qnwpZWWk:-1yc_poI31E:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=1u0qnwpZWWk:-1yc_poI31E:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=1u0qnwpZWWk:-1yc_poI31E:V_sGLiPBpWU" border="0"></img></a>\\n</div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/1u0qnwpZWWk" height="1" width="1" alt=""/>\''

# %%
import base64
print(str(list(output)[2].encode("unicode_escape").decode("utf8")).encode("utf8")) #.decode("unicode_escape"))
# Out:
# b'The Boeing Co Starliner spacecraft that failed in its mission to reach the International Space Station was due to barrel down to the Earth\'s surface early on Sunday with the daunting task of landing safely.<div class="feedflare">\\n<a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=Nm3TKS0f5Ww:EE4xQwCTaD4:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=Nm3TKS0f5Ww:EE4xQwCTaD4:V_sGLiPBpWU" border="0"></img></a>\\n</div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/Nm3TKS0f5Ww" height="1" width="1" alt=""/>'

# %%
print(str(list(output)[2].encode("unicode_escape").decode("utf8")).encode("utf8").decode("unicode_escape"))
# Out:
# The Boeing Co Starliner spacecraft that failed in its mission to reach the International Space Station was due to barrel down to the Earth's surface early on Sunday with the daunting task of landing safely.<div class="feedflare">
# <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:yIl2AUoC8zA"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?d=yIl2AUoC8zA" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:F7zBnMyn0Lo"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=Nm3TKS0f5Ww:EE4xQwCTaD4:F7zBnMyn0Lo" border="0"></img></a> <a href="http://feeds.reuters.com/~ff/reuters/businessNews?a=Nm3TKS0f5Ww:EE4xQwCTaD4:V_sGLiPBpWU"><img src="http://feeds.feedburner.com/~ff/reuters/businessNews?i=Nm3TKS0f5Ww:EE4xQwCTaD4:V_sGLiPBpWU" border="0"></img></a>
# </div><img src="http://feeds.feedburner.com/~r/reuters/businessNews/~4/Nm3TKS0f5Ww" height="1" width="1" alt=""/>

# %%
print (text)
# Out:
# The Boeing Co Starliner spacecraft that failed in its mission to reach the International Space Station was due to barrel down to the Earth's surface early on Sunday with the daunting task of landing safely.
