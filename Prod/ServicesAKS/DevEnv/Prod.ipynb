# %% [markdown]
# **Prod Version of DevEnv**
#
# **This notebook is run using nbconvert after devenv service starts**

# %%
# !pip install twitter
# !pip install feedparser
# !pip install schedule
# !pip install kafka-python
# !pip install redis
# !pip install uuid
# Out:
# Requirement already satisfied: twitter in /opt/conda/lib/python3.7/site-packages (1.18.0)
# Requirement already satisfied: feedparser in /opt/conda/lib/python3.7/site-packages (5.2.1)
# Requirement already satisfied: schedule in /opt/conda/lib/python3.7/site-packages (0.6.0)
# Requirement already satisfied: kafka-python in /opt/conda/lib/python3.7/site-packages (1.4.7)
# Requirement already satisfied: redis in /opt/conda/lib/python3.7/site-packages (3.3.11)
# Requirement already satisfied: uuid in /opt/conda/lib/python3.7/site-packages (1.30)

# %%
from time import sleep
from json import dumps, loads, load
from kafka import KafkaProducer
from datetime import datetime, timedelta
from feedparser import parse
from urllib.request import urlopen
from twitter import Twitter
import schedule
from datetime import datetime
import uuid
from pytz import timezone
from bs4 import BeautifulSoup
import urllib.request 
import pandas as pd

# %%
tickers = ["MSFT","AAPL"]
feeds = ["http://feeds.reuters.com/reuters/businessNews",
         "https://finance.yahoo.com/news/rssindex/", 
         "https://www.nasdaq.com/feed/rssoutbound",
         "https://news.microsoft.com/feed",
        "https://feeds.a.dj.com/rss/WSJcomUSBusiness.xml",
        "https://feeds.a.dj.com/rss/RSSMarketsMain.xml",
        "http://www.marketwatch.com/rss/topstories",
        "http://www.marketwatch.com/rss/marketpulse",
        "http://www.marketwatch.com/rss/realtimeheadlines",
        "http://feeds.marketwatch.com/marketwatch/bulletins",
        "https://www.cnbc.com/id/10000664/device/rss/rss.html",
        "https://www.cnbc.com/id/10001147/device/rss/rss.html",
        "http://feeds.feedburner.com/TechCrunch/",
        "https://www.ft.com/?format=rss",
        "https://rss.nytimes.com/services/xml/rss/nyt/Business.xml",
        "https://abcnews.go.com/abcnews/moneyheadlines",
        "https://www.cbsnews.com/latest/rss/main",
        "https://markets.businessinsider.com/rss/news",
        "http://newsrss.bbc.co.uk/rss/newsonline_uk_edition/front_page/rss.xml",
        "http://feeds.bbci.co.uk/news/business/rss.xml"]

bootstrapping = True
last_time_step = datetime.now(tz=timezone('US/Pacific'))-timedelta(days=3)
output = {}

producer = KafkaProducer(
    bootstrap_servers=['broker:9092'],
    api_version= (0,11),
    value_serializer=lambda x: dumps(x).encode('utf-8'))

# Authenticate with Twitter & search
# https://pypi.org/project/twitter/
# https://developer.twitter.com/en/apps/17019807
from twitter import *
t = Twitter(auth=OAuth(consumer_key="nDwKHutvaskyGecZkCS1SiYY8", consumer_secret="zlQdJIuFUGGglbMO2kYMk6oNLFztzipxhRANNz5q5gqfn1tGb1", token="73568030-GqfoqkfWRhqhARS9uzz51vg1UGSV7AGRaOxDkAurZ", token_secret="1kiHGfyDfO7gcaJbGFnr3lnLA3vXc8ti9hJhj1lnTTvEm"))

# %%
def DownloadStreams():
    # Yahoo Finance Stream for Stock Price
    f_data = {}
    for ticker in tickers:
        try:
            y_finance = load(urlopen("https://query1.finance.yahoo.com/v7/finance/chart/"+ticker+"?range=1h&interval=1h"))
            meta = y_finance['chart']['result'][0]['meta']
            timestamp = meta['regularMarketTime']
            price = meta['regularMarketPrice']
            f_data[ticker] = {"Type": "Finance", "Ticker": ticker, "Timestamp":timestamp, "Price":price}
        except:
            print("Exception in Download Stream for "+ticker)
    
    # News Stream from Reuters for Business
    try:
        if(None == last_time_step):
            last_time_step = datetime.now(tz=timezone('US/Pacific'))-timedelta(days=3)
    except NameError:
        last_time_step = datetime.now(tz=timezone('US/Pacific'))-timedelta(days=3)
        
    feed_data = {}
    for feed in feeds:
        try:
            feed_data[feed] = [{"Type": "News", "Timestamp": datetime.timestamp(pd.to_datetime(l.published)), "Title":l.title, "Summary":BeautifulSoup(l.summary).get_text(strip=True), "Link":l.link} for l in (parse(feed))["entries"] if (pd.to_datetime(l.published)>last_time_step and l.title not in output and len(l.summary)<500)]
        except TypeError:
            print("TypeError")
        # print([l.title for l in d["entries"]])
    
#    if(bootstrapping):
        
    
    last_time_step = datetime.now(tz=timezone('US/Pacific'))-timedelta(days=3)
    for feed in feeds:
        for entry in feed_data[feed]:
            output[entry['Title']]=datetime.fromtimestamp(int(entry['Timestamp']),tz=timezone('US/Pacific'))
        
    deletion_keys = [val for val in output if(output[val]<last_time_step)]
    for key in deletion_keys:
        output.pop(key,None)
    
    return f_data, feed_data

def UploadStreamsToKafka(f_data, feed_data, PopularityOnly=False):
    if(not PopularityOnly):
        for key in f_data.keys():
            producer.send('finance_ticker', value=f_data[key])
        for key in feed_data.keys():
            for entry in feed_data[key]:
                producer.send('news_feed', value=entry)
    # Create Popularity Click Feed
#    for key in feed_data.keys():
#        for entry in feed_data[key]:
#            a = t.search.tweets(q=entry["Title"])
#            for s in a['statuses']:
#                if(s['retweet_count']>0):
#                    producer.send('click',value={'Type': 'Click', 'User': 'generic_'+str(uuid.uuid4()), 'Timestamp': datetime.timestamp(datetime.now()), 'Title': entry["Title"], 'Link': entry["Link"] })
    producer.flush()

def HourlyJob():
    # Check, Download & Parse each stream
    f_data, feed_data = DownloadStreams()
    # Upload cleaned events into Kafka Topics
    UploadStreamsToKafka(f_data, feed_data)
    print("Hourly Run Events Complete - Sleeping now")

def MinutelyJob():
    f_data, feed_data = DownloadStreams()
    UploadStreamsToKafka(f_data, feed_data, True)
    print("Minutely Run Events Complete - Sleeping now")

# %%
HourlyJob()
# Out:
# Hourly Run Events Complete - Sleeping now

# %%
MinutelyJob()
# Out:
# Minutely Run Events Complete - Sleeping now

# %%
schedule.clear()
HourlyJob()

schedule.every(15).minutes.do(HourlyJob)
schedule.every(10).minutes.do(MinutelyJob)
starttime = datetime.now()
endtime = starttime + timedelta(minutes=5)

while True: #datetime.now()<endtime:
    schedule.run_pending()
    sleep(10)
    
schedule.clear()

# %%
output
# Out:
# {'Tesco suspends Chinese supplier after prisoner labor report': datetime.datetime(2019, 12, 22, 2, 17, 17, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The best year financial markets have ever had?': datetime.datetime(2019, 12, 21, 22, 50, 2, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "'Not for the faint of heart:' Critical landing test ahead for Boeing Starliner": datetime.datetime(2019, 12, 21, 22, 28, 43, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Trump says trade deal with China to be signed 'very shortly'": datetime.datetime(2019, 12, 21, 22, 11, 54, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Manager of McDonald's franchise in Peru says faulty drinks machine caused deaths": datetime.datetime(2019, 12, 21, 17, 28, 12, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'NASA, Boeing investigating why Starliner spacecraft missed orbit': datetime.datetime(2019, 12, 21, 13, 18, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "U.S. government says verdict in Bayer's Roundup case should be reversed": datetime.datetime(2019, 12, 21, 12, 54, 17, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Britain gives U.S. investor go-ahead to buy Cobham for $5 billion': datetime.datetime(2019, 12, 21, 8, 49, 45, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Nord Stream 2 to press on with Europe gas pipe, despite U.S. sanctions': datetime.datetime(2019, 12, 21, 0, 55, 6, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Germany 'firmly rejects' U.S. sanctions on Nord Stream 2 firms": datetime.datetime(2019, 12, 21, 6, 16, 43, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Russia gas export pipeline in jeopardy as Trump signs sanctions bill': datetime.datetime(2019, 12, 20, 16, 51, 4, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Russia to go ahead with gas pipe project despite U.S. sanctions': datetime.datetime(2019, 12, 21, 4, 14, 34, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Boeing's failed Starliner mission strains 'reliability' pitch": datetime.datetime(2019, 12, 21, 3, 52, 12, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Russia must press on with Nord Stream 2 gas line to Europe: Russian senator': datetime.datetime(2019, 12, 21, 2, 3, 1, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Wall Street Week Ahead: History suggests rally may slow for U.S. stocks in 2020': datetime.datetime(2019, 12, 21, 0, 57, 43, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Lone Star to buy BASF construction chemicals unit for $3.51 billion': datetime.datetime(2019, 12, 20, 23, 48, 34, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'PG&E creditors offer California wildfire victims $13.5 billion in cash upfront': datetime.datetime(2019, 12, 20, 22, 47, 37, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Boeing's Starliner astronaut capsule fails key test to reach space station": datetime.datetime(2019, 12, 20, 20, 5, 9, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'SEC probes at least two trading firms over NYSE listings: source': datetime.datetime(2019, 12, 20, 16, 50, 7, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'U.S. Steel delivers unwelcome Christmas surprise to Michigan town': datetime.datetime(2019, 12, 20, 16, 48, 53, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'NCAA football bowls: Why schools don&apos;t care about the bonus check': datetime.datetime(2019, 12, 20, 3, 25, 48, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Iran Needs Humanitarian Aid. Trump Should Help.': datetime.datetime(2019, 12, 20, 4, 1, 50, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Commentary: Transportation, Trade Wars And Trade Balances Are All Part Of The Same Equation': datetime.datetime(2019, 12, 20, 8, 53, 4, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Meet the millionaires and billionaires hosting fundraisers for Biden and Buttigieg': datetime.datetime(2019, 12, 20, 5, 37, 4, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Volvo Group Names Lead For New Autonomous Unit': datetime.datetime(2019, 12, 20, 9, 39, 16, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'U.S. Justice Department and FCC fight state effort to block merger of Sprint, T-Mobile': datetime.datetime(2019, 12, 20, 7, 24, 53, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Hedge Funds Watching Geospace Technologies Corp (GEOS) From Afar': datetime.datetime(2019, 12, 20, 7, 17, 40, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Over 267M Facebook users&#39; information exposed: Report': datetime.datetime(2019, 12, 20, 5, 28, 2, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Neil deGrasse Tyson: Commercial space race is about making space cheap': datetime.datetime(2019, 12, 20, 9, 47, 40, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "To IAG's Relief, Heathrow Expansion To Be Delayed": datetime.datetime(2019, 12, 20, 5, 53, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Hedge Funds Are Warming Up To Aytu BioScience, Inc. (AYTU)': datetime.datetime(2019, 12, 21, 12, 43, 38, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'United cancels 737 MAX flights into June as Spirit AeroSystems to freeze parts production': datetime.datetime(2019, 12, 20, 4, 42, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Apple Analyst Raises Price Target Ahead Of 5G iPhone Launch': datetime.datetime(2019, 12, 20, 6, 31, 32, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Bernie Sanders Is the 'Smart Government Candidate,' Adviser Weaver Says": datetime.datetime(2019, 12, 20, 11, 56, 6, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '3 Healthcare Stocks With 100% Street Support': datetime.datetime(2019, 12, 22, 2, 5, 48, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'When Should You Buy SYNNEX Corporation (NYSE:SNX)?': datetime.datetime(2019, 12, 20, 7, 56, 4, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '5 Dividend Stocks That Are Buying Back Their Shares': datetime.datetime(2019, 12, 20, 9, 34, 7, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Fiat Chrysler unions received assurances on jobs, investment after merger': datetime.datetime(2019, 12, 20, 6, 38, 14, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'USD/JPY Weekly Price Forecast &#8211; Dollar Continues To Face Resistance': datetime.datetime(2019, 12, 20, 8, 53, 3, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Here&#39;s What We Think About Kirkland Lake Gold Ltd.&#39;s (TSE:KL) CEO Pay': datetime.datetime(2019, 12, 20, 6, 18, 7, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '3 Stocks to Sell and Kiss Goodbye Before the New Year': datetime.datetime(2019, 12, 20, 10, 30, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Government study finds racial bias in facial-recognition tech': datetime.datetime(2019, 12, 20, 13, 29, 56, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Is Great Panther Mining Limited (GPL) Going To Burn These Hedge Funds ?': datetime.datetime(2019, 12, 20, 15, 37, 48, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Bitcoin edges towards major bull market reversal': datetime.datetime(2019, 12, 20, 3, 0, 45, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The Crypto Daily – Movers and Shakers -22/12/19': datetime.datetime(2019, 12, 21, 16, 31, 35, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Why Disney&#39;s Bob Iger could face greater hurdles in 2020 as &#39;The Last Jedi&#39; gets hit with dour reviews': datetime.datetime(2019, 12, 21, 5, 0, 53, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Veeva Systems Inc. (NYSE:VEEV) Earns A Nice Return On Capital Employed': datetime.datetime(2019, 12, 20, 11, 10, 18, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'We Tested Your Tesla Knowledge. Here Are The Results.': datetime.datetime(2019, 12, 21, 8, 35, 13, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Novartis wins Medicaid approval for new sickle cell drug in key U.S. states': datetime.datetime(2019, 12, 20, 3, 3, 49, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Wilbur Ross Says Tariffs Are Working Despite U.S. Steel Layoffs': datetime.datetime(2019, 12, 20, 13, 5, 1, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Hedge Funds Have Never Been This Bullish On HOOKIPA Pharma Inc. (HOOK)': datetime.datetime(2019, 12, 20, 11, 27, 55, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Netflix to rally 30% on &#39;international potential&#39; in 2020: RBC': datetime.datetime(2019, 12, 20, 11, 56, 10, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'EOS, Ethereum and Ripple’s XRP &#8211; Daily Tech Analysis – 22/12/19': datetime.datetime(2019, 12, 21, 18, 15, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Amid shift to online liquor buys, here&#39;s why startup Drizly sees delivery as a &#39;commodity&#39;': datetime.datetime(2019, 12, 21, 5, 0, 53, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'HEICO Corporation Just Released Its Yearly Earnings: Here&#39;s What Analysts Think': datetime.datetime(2019, 12, 20, 5, 33, 21, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'A Look At The Fair Value Of Suncor Energy Inc. (TSE:SU)': datetime.datetime(2019, 12, 20, 9, 59, 10, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'S&amp;P 500 Weekly Price Forecast &#8211; Stock Markets Continue To Rocket Higher': datetime.datetime(2019, 12, 20, 9, 47, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Unhappy Birthday? Trump Tax Cuts Turn 2': datetime.datetime(2019, 12, 20, 15, 47, 54, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Carnival Sails on 4th-Quarter and Renewed Outlook Optimism': datetime.datetime(2019, 12, 20, 13, 43, 1, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '30 Reasons It’s Hard to Retire at 65': datetime.datetime(2019, 12, 20, 10, 32, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Tipping: Most Americans aren&#39;t tipping many service providers': datetime.datetime(2019, 12, 21, 5, 1, 8, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Why America’s economy needs immigrants': datetime.datetime(2019, 12, 20, 7, 49, 11, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Estimating The Fair Value Of Caterpillar Inc. (NYSE:CAT)': datetime.datetime(2019, 12, 21, 4, 23, 52, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Bargains in the Energy Sector Attract Top Value Investors': datetime.datetime(2019, 12, 20, 8, 17, 36, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Voters will realize they &#39;just won&#39;t survive&#39; with Trump as president, says activist DeRay Mckesson': datetime.datetime(2019, 12, 21, 4, 23, 13, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Here&#39;s Why I Think Intel (NASDAQ:INTC) Might Deserve Your Attention Today': datetime.datetime(2019, 12, 21, 5, 38, 6, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Weighing The Week Ahead: Are Investors Too Complacent?': datetime.datetime(2019, 12, 22, 1, 54, 41, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Asian Shares Finish Week Higher on Back of Trade Deal, Strong Chinese Industrial, Retail Data': datetime.datetime(2019, 12, 21, 19, 1, 39, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Skyworks Solutions vs. Qorvo: Which Is the Better 5G Stock?': datetime.datetime(2019, 12, 21, 16, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '3 Dividend Stocks That Are Perfect for Retirement': datetime.datetime(2019, 12, 21, 15, 31, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Disney's New Star Wars Ride Is a Game Changer": datetime.datetime(2019, 12, 21, 15, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Will Amazon Make a Dent in Cisco's Revenue With This New Project?": datetime.datetime(2019, 12, 21, 14, 45, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Micron Optimism Grows on 5G Potential, New Video Game Consoles': datetime.datetime(2019, 12, 21, 14, 5, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'You Might Never See These 5 Popular Tax Deductions Again': datetime.datetime(2019, 12, 21, 14, 3, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'These 3 Value Stocks Are Absurdly Cheap Right Now': datetime.datetime(2019, 12, 21, 13, 38, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '3 Ways You Can Lose Your Social Security Benefits': datetime.datetime(2019, 12, 21, 13, 30, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "The Top 10 Costs That Young Adults Need Parents' Help With": datetime.datetime(2019, 12, 21, 13, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Is This Latin America Telecom Stock a Buy?': datetime.datetime(2019, 12, 21, 12, 41, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  '5 Rock-Solid Dividend Stocks to Buy Yielding at Least 5%': datetime.datetime(2019, 12, 21, 12, 16, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "If You Had Invested $1,000 in Comcast's IPO, Here's How Much Money You'd Have Now": datetime.datetime(2019, 12, 21, 12, 5, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Microsoft and KKBOX Group launch global strategic partnership': datetime.datetime(2019, 12, 20, 11, 0, 16, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The chassis of the future is code: ZF collaborates with Microsoft to become a provider of software solutions': datetime.datetime(2019, 12, 20, 5, 59, 15, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Ericsson and Microsoft team up for the next generation of connected cars': datetime.datetime(2019, 12, 20, 5, 55, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Last minute US holiday deals available now at Microsoft Store': datetime.datetime(2019, 12, 19, 18, 22, 52, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Dawn of a decade: The top 10 tech policy issues for the 2020s': datetime.datetime(2019, 12, 19, 7, 56, 22, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'How tech intensity accelerates business value': datetime.datetime(2019, 12, 19, 7, 41, 30, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Developing a quantum computing-ready global workforce': datetime.datetime(2019, 12, 19, 7, 36, 32, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Banks Get Tough on Shale Loans as Fracking Forecasts Founder': datetime.datetime(2019, 12, 22, 2, 30, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The Newest Trend in Holiday Gifting? Old Stuff': datetime.datetime(2019, 12, 21, 5, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Boeing's Crisis Spreads Beyond MAX": datetime.datetime(2019, 12, 20, 16, 14, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'SEC Probes Listings of Slack, Other Unicorns on NYSE': datetime.datetime(2019, 12, 20, 14, 37, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Walmart's Secret Weapon to Fight Off Amazon: The Supercenter": datetime.datetime(2019, 12, 21, 3, 5, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Consumer Spending Strengthens as Year Winds Down': datetime.datetime(2019, 12, 20, 10, 21, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'When Congress Buys Time to Finish a Budget, the Price Is Uncertainty': datetime.datetime(2019, 12, 20, 19, 35, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'With Brexit Looming, U.K. Picks Veteran as Central Bank Chief': datetime.datetime(2019, 12, 20, 6, 37, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'U.S. Home Sales Pick Up in Second Half of Year': datetime.datetime(2019, 12, 19, 12, 55, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'House Passes North American Trade Pact With Bipartisan Support': datetime.datetime(2019, 12, 19, 14, 46, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'A Genetic Test Led Seven Women in One Family to Have Major Surgery. Then the Odds Changed.': datetime.datetime(2019, 12, 20, 8, 43, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Trump Administration Backs Bayer in Weedkiller Court Fight': datetime.datetime(2019, 12, 20, 14, 44, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Facebook, Twitter Remove AI-Powered Fake Accounts With Pro-Trump Messages': datetime.datetime(2019, 12, 20, 15, 58, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'DOJ, FCC Support T-Mobile, Sprint in Antitrust Fight With States': datetime.datetime(2019, 12, 20, 12, 39, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'BASF to Sell Construction Chemicals Business to Lone Star Funds': datetime.datetime(2019, 12, 21, 4, 53, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'IAC to Buy Care.com in $500 Million Cash Deal': datetime.datetime(2019, 12, 20, 12, 47, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Travis Kalanick Cuts Uber Stake by More Than 90%': datetime.datetime(2019, 12, 21, 13, 47, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The Leadership Case for Saving High-School Football': datetime.datetime(2019, 12, 20, 21, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Marijuana's Money Man": datetime.datetime(2019, 12, 20, 11, 15, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Russian Markets Rally as Investors Look Past U.S. Sanctions': datetime.datetime(2019, 12, 22, 2, 30, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'An $809 Car Payment, a $660 Income: How Dealers Make It Work': datetime.datetime(2019, 12, 21, 2, 30, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Inheriting IRAs Just Got Complicated, Thanks to New Retirement Overhaul': datetime.datetime(2019, 12, 20, 21, 1, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'FedEx, Bed Bath & Beyond, Netflix: Stocks That Defined the Week': datetime.datetime(2019, 12, 20, 15, 34, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Nasdaq Prevails in Lawsuit Over Stolen ETF': datetime.datetime(2019, 12, 20, 15, 21, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Behind the Biotech Stock Rally: New Deals and Easing Political Worries': datetime.datetime(2019, 12, 20, 14, 40, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Stocks Climb Again to Highs': datetime.datetime(2019, 12, 20, 14, 37, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Invesco to Close Dozens of ETFs in 2020 as Fund Shakeout Continues': datetime.datetime(2019, 12, 20, 14, 23, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Inflation-Protected Bonds Gain Favor After Trade Deal, Fed Signs': datetime.datetime(2019, 12, 20, 14, 19, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Bulls Return as S&P 500 Cruises Toward Best Week in Months': datetime.datetime(2019, 12, 20, 13, 41, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Despite Initial Trade Deal, Analysts Still Project Plentiful Crude in 2020': datetime.datetime(2019, 12, 20, 11, 59, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The Consumer Lives On, but Carefully': datetime.datetime(2019, 12, 20, 10, 7, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Disney Critics Are No Phantom Menace': datetime.datetime(2019, 12, 20, 7, 36, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  "Nestlé's Food Pairings Are Best in Small Doses": datetime.datetime(2019, 12, 20, 7, 26, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Fed Adds $26.7 Billion in Liquidity to Markets': datetime.datetime(2019, 12, 20, 7, 25, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'The Fund That Does a Lot by Doing Nothing': datetime.datetime(2019, 12, 20, 7, 11, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Stocks to Watch: Nike, AAR, CarMax, CalAmp, BlackBerry': datetime.datetime(2019, 12, 20, 5, 39, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'Investors Blindsided as Europe Upends Dispute-Resolution System': datetime.datetime(2019, 12, 20, 5, 11, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>),
#  'What to Know About Changes Coming to Retirement Plans': datetime.datetime(2019, 12, 20, 4, 0, tzinfo=<DstTzInfo 'US/Pacific' PST-1 day, 16:00:00 STD>)}
